# %% [markdown]
# <a href="https://colab.research.google.com/github/InsightfulSantosh/Machine-Learning/blob/main/Feature_Engineering_for_Interpretable_Models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Session Flow**:

# %% [markdown]
# * **Learning Objective**
#  - Introduction
#  - Theme
#  - Primary Goals
#
# * **Learning Material**
#  * **What is Feature Engineering?**
#  * Why do we need it?
#  * What is feature understanding?
#  * **Basic EDA**
#    - Univariate Analysis
#    - Bivariate analysis
#    - Multivariate Analysis
#  * Activity 1 : Fill in the Blanks
#  * **Other methods for Feature Engineering**
#    - Handling Imbalanced Dataset
#    - Feature Selection
#    - Dimensionality Reduction
#       - Principal Component Analysis
#   * Activity 2: True or False
#
# * **Summary**
#    - What did you learn?
#    - Best Practices/Tips
#    - Shortcomings
#
# * **Enhance Your Knowledge**
#    - Additional Resources
#    - Mnemonic
#
# * **Try it Yourself**
#    - Take Home Assignment
#    - Social Engagement

# %% [markdown]
# # **👨🏻‍🎓 Learning Objective 👨🏻‍🎓**

# %% [markdown]
# ## **Introduction**
# Feature engineering is a crucial aspect of building interpretable machine learning models. It involves crafting new features or modifying existing ones from raw data to enhance the model's interpretability and predictive performance. In this lesson, we delve into the world of "Feature Engineering for Interpretable Models" and explore various techniques to optimize data and improve model interpretability. 🎯🔍💡
#
#
# ##**Theme**
# 🌐 Welcome to "Feature Engineering for Interpretable Models"! 🚀🔍💡
#
# In today's data-driven world, feature engineering is essential for unlocking the power of interpretability in supervised learning. By crafting meaningful features from raw data, we can make accurate data-driven predictions and unravel hidden insights.
#
# 💼 Companies like Amazon, GE Healthcare, and PayPal leverage feature engineering to enhance customer experience, predict disease progression, and safeguard financial systems.
#
# 🏦 In finance, feature engineering detects suspicious patterns, ensuring secure transactions, while in education, it personalizes learning experiences for students.
#
# 🎵 Music streaming services like Spotify use feature engineering to curate personalized playlists, and automotive companies like Tesla engineer features for autonomous vehicles.
#
# 🚀 Embark on this thrilling journey of Feature Engineering for Interpretable Models! Let's explore real-life examples and unleash the potential of data-driven decision-making! 🌟🧭📈
#
# ## **Primary Goals**
#
# * Perform univariate analysis to understand individual feature distributions and characteristics.
#
# * Conduct bivariate analysis to explore relationships between pairs of features.
# Utilize multivariate analysis to study interactions between multiple features simultaneously.
#
# * Handle missing values effectively to avoid bias and maintain data integrity.
#
# * Detect and address outliers to prevent them from influencing model performance.
#
# * Encode categorical variables appropriately to incorporate them into interpretable models.
#
# * Transform data using techniques like log transformation, square root, or Box-Cox to meet model assumptions.
#
# * Handle imbalanced datasets using techniques such as oversampling or undersampling to ensure model fairness and accuracy.
#
# * Apply data reduction techniques like PCA (Principal Component Analysis) to simplify the feature space while preserving relevant information.
#
# * Perform feature selection to identify and retain the most important features, reducing model complexity and improving interpretability.

# %% [markdown]
# # **📖 Learning Material 📖**

# %% [markdown]
# ## **What is Feature Engineering?**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Feature engineering is a process of transforming the given data into a form which is easier to interpret. Here, we are interested in making it more transparent for a machine learning model, but some features can be generated so that the data visualization prepared for people without a data-related background can be more digestible. However, the concept of transparency for the machine learning models is a complicated thing as different models often require different approaches for the different kinds of data.

# %% [markdown]
# Feature engineering is an informal topic, and there are many possible definitions. The machine learning workflow is fluid and iterative, so there’s no one “right answer.”
#
# In a nutshell, we define feature engineering as creating new features from your existing ones to improve model performance.

# %% [markdown]
# ### **Why do we need it?**

# %% [markdown]
# The intention of feature engineering is to achieve two primary goals:
#
# 1.	Preparing an input dataset that is compatible with and best fits the machine learning algorithm.
#
# 2.	Improving the performance of machine learning models
#
# According to a survey in Forbes, data scientists spend 80% of their time on data preparation. The importance of feature engineering is realized through its time-efficient approach to preparing data that brings consistent output.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# When feature engineering processes are executed well, the resulting dataset will be optimal and contain all the essential factors that bear an impact on the business problem. These datasets in turn result in best possible predictive models and most beneficial insights.

# %% [markdown]
# #### **What is feature understanding and why is it important?**
#
# Feature understanding refers to the process of gaining insights, knowledge, and a deep understanding of the features or variables used in a machine learning or data analysis task. It involves comprehending the nature, characteristics, and significance of each feature in a dataset. Feature understanding is a critical step in the data preprocessing and feature engineering stages of a data science project. Here's why it is important:
#
# 1. **Data Quality Assessment:** Understanding the features helps assess the quality of the data. It allows you to identify missing values, outliers, and anomalies associated with each feature. Data quality issues can significantly impact model performance, so addressing them is essential.
#
# 2. **Feature Selection:** Not all features are equally important for modeling. Feature understanding helps you determine which features are relevant and informative for the task at hand. It enables feature selection, where you choose the most relevant features and exclude irrelevant ones, simplifying the model and potentially improving its performance.
#
# 3. **Feature Engineering:** Feature understanding guides the feature engineering process. You can transform, combine, or create new features based on your understanding of the domain and the relationships between variables. Feature engineering can enhance a model's ability to capture patterns and relationships in the data.
#
# 4. **Domain Knowledge Integration:** Feature understanding allows you to incorporate domain knowledge into the modeling process. Understanding the meaning and context of features helps you make informed decisions about how to preprocess the data and which features are likely to have a significant impact on the outcome.
#
# 5. **Model Interpretability:** Knowing the features intimately helps interpret the model's predictions. You can explain why the model makes certain predictions by referring to the importance and relationships of specific features. This is crucial for making the model's decisions more transparent and trustworthy.
#
# 6. **Dimensionality Reduction:** In high-dimensional datasets, feature understanding aids in dimensionality reduction. You can identify redundant or highly correlated features, reducing the number of dimensions while preserving relevant information.
#
# 7. **Model Performance:** Understanding the features can lead to better model performance. By selecting, engineering, and preprocessing features effectively, you can create a dataset that aligns with the assumptions of the chosen machine learning algorithm, leading to improved model accuracy and generalization.
#
# 8. **Data Bias and Fairness:** Feature understanding helps detect biases in the data, such as demographic or sampling biases. This is crucial for addressing fairness concerns and ensuring that machine learning models do not perpetuate or amplify biases present in the data.
#
# 9. **Data Visualization:** Visualizing data is an integral part of feature understanding. It allows you to explore relationships between features, identify patterns, and detect outliers. Data visualization tools and techniques support the exploration of feature distributions and interactions.
#
# 10. **Data Cleaning and Preprocessing:** Feature understanding informs data cleaning and preprocessing steps. You can make informed decisions about how to handle missing data, outliers, and categorical variables based on your understanding of the features.
#
# In summary, feature understanding is a foundational step in any data science or machine learning project. It empowers data scientists and analysts to make informed decisions throughout the data pipeline, from data cleaning and preprocessing to model selection and interpretation. A deep understanding of features enhances the quality, transparency, and effectiveness of machine learning models.

# %% [markdown]
# ## **Basic EDA**

# %% [markdown]
# ### **1. Univariate Analysis**

# %% [markdown]
# Univariate analysis is the simplest form of analyzing data. “Uni” means “one”, so in other words your data has only one variable. It doesn’t deal with causes or relationships (unlike regression ) and it’s major purpose is to describe; It takes data, summarizes that data and finds patterns in the data.
#
# Ex:- CDF, PDF, Box plot, Violin plot.

# %% [markdown]
# ![univariate.png](data:image/png;base64,...)

# %% [markdown]
# ### **2. Bivariate analysis**

# %% [markdown]
# Bivariate analysis means the analysis of bivariate data. It is one of the simplest forms of statistical analysis, used to find out if there is a relationship between two sets of values. It usually involves the variables X and Y. The results from bivariate analysis can be stored in a two-column data table.
#
# Ex:- Box plot, Scatter Plot,Violin plot, Joint plot.

# %% [markdown]
# ![1_SSy0gFmPCLaiopHaCxFq-Q.png](data:image/png;base64,...)![1_dWiGaB9y9cbmXSnh-0eMMA.png](data:image/png;base64,...)

# %% [markdown]
# ### **3.	Multivariate Analysis**

# %% [markdown]
# Multivariate means more than one variable behind the resultant outcome. Anything that happens in the world or business is not due to one reason but multiple reasons behind the outcome known as multivariate. As an example, Weather is dependent on multiple factors like pollution, precipitation, humidity to name a few.
#
# Ex:- Pair Plot, 3D Scatter Plot.

# %% [markdown]
# ![1_NFflDpjmSi9XNNw9RRTEeg.png](data:image/png;base64,...)

# %% [markdown]
# ### **Activity 1 : Fill in the Blanks**
# 1. Univariate analysis deals with ______________ variable(s) in the data.
# 2. Bivariate analysis involves analyzing the relationship between _______________ sets of values.
# 3. Multivariate analysis considers more than one _______________ behind the resultant outcome.
# 4. Pair Plot is an example of a ________________ technique.

# %% [markdown]
# #### **Activity 1 Answers**
# 1. One variable(s) in the data.
# 2. Two sets of values.
# 3. Variable.
# 4. Multivariate technique.

# %% [markdown]
# ## **Handling Imbalanced Dataset**

# %% [markdown]
# The class imbalance problem in machine learning refers to situations where the classes (categories) in the dataset are not represented equally. This imbalance can significantly skew the performance of machine learning models, especially those that assume an equal or similar distribution of classes.
#
# Here are some key points about the class imbalance problem:
#
# 1. **Definition**: Class imbalance occurs when there are significantly more instances of some classes than others in the dataset. For example, in a binary classification problem, you might have a lot of examples for one class (the majority class) and very few for the other (the minority class).
#
# 2. **Impact on Model Performance**: Most machine learning algorithms are designed to maximize overall accuracy, which can be misleading when the classes are imbalanced. They tend to be biased towards the majority class, as correctly predicting the majority class most of the time can still achieve high accuracy.
#
# 3. **Real-world Examples**: Class imbalance is common in real-world scenarios. For example, in fraud detection, the number of fraudulent transactions is typically much smaller compared to legitimate transactions. In medical diagnosis, the number of patients with a rare disease is usually much lower than those without it.
#
# 4. **Strategies to Address the Issue**:
#    - **Resampling Techniques**: Balancing the dataset by either oversampling the minority class or undersampling the majority class.
#    - **Algorithmic Level Solutions**: Using algorithms that are inherently more robust to class imbalance, such as tree-based methods.
#    - **Cost-Sensitive Learning**: Assigning a higher cost to misclassifying the minority class.
#    - **Evaluation Metrics**: Using metrics that are more informative than accuracy in imbalanced settings, such as precision, recall, F1-score, or the area under the ROC curve.
#
# 5. **Consideration of Data Quality**: While addressing class imbalance, it's also important to maintain the quality and representativeness of the data. Simply adding more samples of the minority class (through techniques like synthetic data generation) or removing samples from the majority class can sometimes lead to overfitting or loss of important information.
#
# Understanding and effectively handling class imbalance is crucial for developing models that perform well in real-world conditions, where balanced datasets are often not the norm.

# %% [markdown]
# ### **Problem Statement: Let’s say we have a dataset of credit card companies where we have to find out whether the credit card transaction was fraudulent or not.**
#
# But here’s the catch… the fraud transaction is relatively rare, only 6% of the transaction is fraudulent.
#
# Now, before you even start, do you see how the problem might break? Imagine if you didn’t bother training a model at all. Instead, what if you just wrote a single line of code that always predicts ‘no fraudulent transaction’.
#
# ```
# def transaction(transaction_data):
#     return 'No fradulent transaction'
# ```

# %% [markdown]
# **Dataset Link:** https://drive.google.com/file/d/1S-LAnh8WFKmvj-2HNXcD9niOzHxKj__f/view?usp=sharing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_auc_score, confusion_matrix, accuracy_score

# %%
data = pd.read_csv('fraudtransactions.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  Feature_1  Feature_2  Feature_3  Feature_4  Feature_5  Fraud
# 0           0   1.021519  -0.548166  -2.079610   2.988799  -2.282637      0
# 1           1   0.210297   0.378811  -1.558116   1.737750  -2.083806      0
# 2           2   0.312219   0.266673  -0.873507   2.422799  -2.373239      0
# 3           3   0.613577  -0.487993  -1.824985   2.346751  -2.172025      0
# 4           4  -0.062001  -0.837709  -1.414938   1.124668  -1.826684      0

# %%
data['Fraud'].value_counts()
# Out:
# 0    990
# 1     10
# Name: Fraud, dtype: int64

# %% [markdown]
# #### The Metric Trap
#
# One of the major issues when dealing with unbalanced datasets relates to the metrics used to evaluate their model. Using simpler metrics like accuracy score can be misleading. In a dataset with highly unbalanced classes, the classifier will always “predict” the most common class without performing any analysis of the features and it will have a high accuracy rate, obviously not the correct one.

# %%
# Creating the dataset with all independent variables
X = data.iloc[:,:-1]

# Creating the dataset with the dependent variable
Y = data.iloc[:,-1]

# %%
# Splitting the dataset into the Training set and Test set
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 3)

# %%
print("Distribution of classes of dependent variable in train :")
print(Y_train.value_counts())

print("\n Distribution of classes of dependent variable in test :")
print(Y_test.value_counts())
# Out:
# Distribution of classes of dependent variable in train :
# 0    792
# 1      8
# Name: Fraud, dtype: int64
#
#  Distribution of classes of dependent variable in test :
# 0    198
# 1      2
# Name: Fraud, dtype: int64

# %%
classifier = LogisticRegression()
classifier.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %%
y_pred = classifier.predict(X_test)

# %%
accuracy_score(y_pred, Y_test)
# Out:
# 1.0

# %% [markdown]
# **This accuracy is very much misleading as our data is imbalanced.**

# %% [markdown]
# ### Resampling Techniques
#
# A widely adopted technique for dealing with highly unbalanced datasets is called resampling. It consists of removing samples from the majority class (under-sampling) and/or adding more examples from the minority class (over-sampling).
#
# ![Screenshot 2020-12-26 at 3.30.55 AM.png](data:image/png;base64,...)

# %% [markdown]
# Despite the advantage of balancing classes, these techniques also have their own weaknesses.
#
# The simplest implementation of over-sampling is to duplicate random records from the minority class, which can cause overfitting.
#
# In under-sampling, the simplest technique involves removing random records from the majority class, which can cause loss of information.

# %% [markdown]
# Let’s implement this with the fraud detection example.
#
# We will start by separating the class that will be 0 and class 1.

# %%
# Class count
class_count_0, class_count_1 = data['Fraud'].value_counts()

# Separate class
class_0 = data[data['Fraud'] == 0]
class_1 = data[data['Fraud'] == 1]
print('class 0:', class_0.shape)
print('class 1:', class_1.shape)
# Out:
# class 0: (990, 7)
# class 1: (10, 7)

# %% [markdown]
# #### 1. **Random Under-Sampling**
#
# Undersampling can be defined as removing some observations of the majority class. This is done until the majority and minority class is balanced out.
#
# Undersampling can be a good choice when you have a ton of data -think millions of rows. But a drawback to undersampling is that we are removing information that may be valuable.

# %%
from imblearn.under_sampling import RandomUnderSampler

rus = RandomUnderSampler(random_state=42, replacement=True)
x_rus, y_rus = rus.fit_resample(data.iloc[:,0:-1], data['Fraud'])

print('Original dataset shape:', len(data))
print('Resampled dataset shape', len(y_rus))
# Out:
# Original dataset shape: 1000
# Resampled dataset shape 20

# %% [markdown]
# #### 2. **Random Over-Sampling**
#
# Oversampling can be defined as adding more copies to the minority class. Oversampling can be a good choice when you don’t have a ton of data to work with.
#
# A con to consider when oversampling is that it can cause overfitting and poor generalization to your test set.

# %%
from imblearn.over_sampling import RandomOverSampler

ros = RandomOverSampler(random_state=42)
x_ros, y_ros = ros.fit_resample(data.iloc[:,0:-1], data['Fraud'])

print('Original dataset shape:', len(data))
print('Resampled dataset shape', len(y_ros))
# Out:
# Original dataset shape: 1000
# Resampled dataset shape 1980

# %% [markdown]
# #### 3. **Under-Sampling: Tomek links**
#
# Tomek links are pairs of very close instances but of opposite classes. Removing the instances of the majority class of each pair increases the space between the two classes, facilitating the classification process.
#
# Tomek’s link exists if the two samples are the nearest neighbors of each other.
#
# ![Screenshot 2020-12-26 at 3.47.53 AM.png](data:image/png;base64,...)

# %%
from imblearn.under_sampling import TomekLinks

tl = TomekLinks(sampling_strategy='majority')

X_tl, y_tl = tl.fit_resample(data.iloc[:,0:-1], data['Fraud'])

print('Original dataset shape:', len(data))
print('Resampled dataset shape', len(y_tl))
# Out:
# Original dataset shape: 1000
# Resampled dataset shape 1000

# %% [markdown]
# #### 4. **Synthetic Minority Oversampling Technique (SMOTE)**
#
# This technique generates synthetic data for the minority class.
#
# SMOTE (Synthetic Minority Oversampling Technique) works by randomly picking a point from the minority class and computing the k-nearest neighbors for this point. The synthetic points are added between the chosen point and its neighbors.
#
# ![Screenshot 2020-12-26 at 3.53.10 AM.png](data:image/png;base64,...)

# %% [markdown]
# SMOTE algorithm works in 4 simple steps:
#
# * Choose a minority class as the input vector
# * Find its k nearest neighbors (k_neighbors is specified as an argument in the SMOTE() function)
# * Choose one of these neighbors and place a synthetic point anywhere on the line joining the point under consideration and its chosen neighbor
# * Repeat the steps until data is balanced

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE()

# fit predictor and target variable
x_smote, y_smote = smote.fit_resample(data.iloc[:,0:-1], data['Fraud'])

print('Original dataset shape', len(data))
print('Resampled dataset shape', len(y_smote))
# Out:
# Original dataset shape 1000
# Resampled dataset shape 1980

# %% [markdown]
# ### **Choose the evaluation metric wisely**
#
# Accuracy is not the best metric to use when evaluating imbalanced datasets as it can be misleading.
#
# Metrics that can provide better insight are:
#
# * **Confusion Matrix**: a table showing correct predictions and types of incorrect predictions.
# * **Precision**: the number of true positives divided by all positive predictions. Precision is also called Positive Predictive Value. It is a measure of a classifier’s exactness. Low precision indicates a high number of false positives.
# * **Recall**: the number of true positives divided by the number of positive values in the test data. The recall is also called Sensitivity or the True Positive Rate. It is a measure of a classifier’s completeness. Low recall indicates a high number of false negatives.
# * **F1 Score**: the weighted average of precision and recall.
# * **Area Under ROC Curve (AUC-ROC)**: AUC-ROC represents the likelihood of your model distinguishing observations from two classes. In other words, if you randomly select one observation from each class, what’s the probability that your model will be able to “rank” them correctly?

# %% [markdown]
# ##**Feature selection: Techniques and their applicability**

# %% [markdown]
# Feature selection is a crucial step in the data analysis and machine learning process. Think of it as deciding what ingredients to put in a recipe. Just like in cooking, where using too many or the wrong ingredients can spoil a dish, in data analysis, using too many or irrelevant features (which are like individual ingredients for your data recipe) can make your analysis or model less effective. Here's why feature selection is important:
#
# 1. **Improves Model Performance:** Using only relevant features can help your model perform better. It's like focusing on the ingredients that really matter for your dish to taste great.
#
# 2. **Reduces Complexity:** Fewer features mean simpler models. Simpler models are generally easier to understand and faster to run, just like a simpler recipe is easier to follow and quicker to cook.
#
# 3. **Avoids Overfitting:** Overfitting is when a model is too closely tailored to the training data and doesn’t perform well on new, unseen data. It's like a recipe that’s perfect for one specific occasion but doesn’t work well for others. Feature selection helps avoid this by removing irrelevant or redundant data.
#
# 4. **Easier Interpretation:** With fewer features, it’s easier to understand the results and explain them to others. A simple recipe with fewer ingredients is easier to explain than one with dozens of components.
#
# 5. **Faster Training Time:** Fewer features mean less data for the model to process, which can speed up the training process. It’s like cooking a meal faster because you have fewer ingredients to prepare.
#
# 6. **Reduces Risk of Errors:** Each additional feature introduces a chance of errors, either in the data itself or in how the model processes it. Fewer features can mean fewer opportunities for errors.
#
# 7. **Improves Data Quality:** Feature selection can help you identify and remove data that doesn't contribute to your analysis or might even be misleading.
#
# In summary, feature selection helps you choose the right data for your analysis, much like choosing the right ingredients for a recipe. This can make your models simpler, faster, more accurate, and easier to understand.

# %% [markdown]
# ![ezgif-2-4606fb2f10.gif](data:image/gif;base64,...)

# %% [markdown]
# Feature selection is a crucial step to identify the most relevant and informative features for our analysis. Let's explore some popular techniques and their applicability, with engaging descriptions! 🧩📊

# %% [markdown]
# ##### <u>**Example:**</u>

# %% [markdown]
# Let's create a simple data frame where we will observe that some features do not contribute to the model performance:

# %% [markdown]
# **Step 1: Create Sample Dataset with Random Features**
# We'll create a dataset with a few random features and a target variable.
#
# **Step 2: Add a Constant Feature to the Dataset**
# Now, we'll add a constant feature to our dataset. This feature will have the same value for all observations. Let's add this feature and then proceed with fitting a linear regression model.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Creating a sample dataset with random features
np.random.seed(0)  # Seed for reproducibility
sample_data = {
    'feature1': np.random.rand(100),
    'feature2': np.random.rand(100),
    'feature3': np.random.rand(100),
    'target': np.random.randint(0, 2, 100)  # Binary target
}

sample_df = pd.DataFrame(sample_data)
# Adding a constant feature to the dataset
sample_df['constant_feature'] = 1

# Display the first few rows of the dataframe
sample_df.head()
# Out:
#    feature1  feature2  feature3  target  constant_feature
# 0  0.548814  0.677817  0.311796       0                 1
# 1  0.715189  0.270008  0.696343       0                 1
# 2  0.602763  0.735194  0.377752       1                 1
# 3  0.544883  0.962189  0.179604       1                 1
# 4  0.423655  0.248753  0.024679       1                 1

# %% [markdown]
# Let's visualize how the constant feature is related to the target variable.

# %%
# Scatter plot for Constant Feature vs Target
plt.figure(figsize=(6, 4))
sns.lineplot(data=sample_df, x='constant_feature', y='target')
plt.title("Constant Feature vs Target")
plt.show()

# %% [markdown]
# **Step 3: Fit a Linear Regression Model and Evaluate Performance**
#
# Next, we'll fit a linear regression model to this data, including the constant feature. We'll then evaluate the model's performance using the mean squared error (MSE). This will help us understand the impact of the constant feature on the model.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# Preparing the data for modeling
X_sample = sample_df.drop('target', axis=1)
y_sample = sample_df['target']


# Fit the linear regression model
model_sample = LinearRegression()
model_sample.fit(X_sample, y_sample)

# Make predictions and calculate MSE
predictions = model_sample.predict(X_sample)

mse = mean_squared_error(y_sample, predictions)

mse
# Out:
# 0.24326191926347882

# %% [markdown]
# The Mean Squared Error (MSE) for our model is approximately 0.24326. This gives us an initial indication of the model's performance, including the constant feature.

# %% [markdown]
# Variance Inflation Factor (VIF) is a measure used primarily to detect multicollinearity among predictors within a multiple regression model. However, it can also be indirectly used as a feature selection method, particularly in the context of linear models. Here's how it works and how it can be applied in feature selection:
#
# 1. **Purpose**: VIF assesses how much the variance of an estimated regression coefficient increases if your predictors are correlated. A high VIF indicates that the predictor is highly collinear with the other predictors, and therefore, its coefficient is not well estimated.
#
# 2. **Calculation**: For each predictor variable, a VIF value is calculated. It's the ratio of variance in a model with multiple terms, divided by the variance of a model with one term alone. Mathematically, $( \text{VIF}_i = \frac{1}{1 - R_i^2})$, where $( R_i^2)$ is the coefficient of determination of a regression of predictor $( i)$ on all the other predictors.

# %% [markdown]
# **Step 4: Calculate VIF**
#
# Now, we'll calculate the Variance Inflation Factor (VIF) for each feature. This will help us assess the impact of multicollinearity, especially the influence of the constant feature. High VIF values can indicate problematic multicollinearity. Let's see how the constant feature affects the VIF values.

# %%
import pandas as pd
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calculate_vif(dataframe):
    vif_data = pd.DataFrame()
    vif_data["feature"] = dataframe.columns

    # Calculating VIF for each feature
    vif_data["VIF"] = [variance_inflation_factor(dataframe.values, i) for i in range(len(dataframe.columns))]
    return vif_data

vif_sample_df = calculate_vif(X_sample)

vif_sample_df
# Out:
#             feature        VIF
# 0          feature1   1.006442
# 1          feature2   1.020808
# 2          feature3   1.017704
# 3  constant_feature  11.867552

# %% [markdown]
# **Interpretation**:
#    - A VIF of 1 means that the predictor is not correlated with other variables.
#    - A VIF between 1 and 5 typically indicates moderate correlation, but it's often not severe enough to require attention.
#    - A VIF above 5 or 10 (thresholds can vary based on the field of study) suggests high correlation that may be problematic.

# %% [markdown]
# **Fit a New Linear Regression Model**
#
# Now, let's fit a new linear regression model using the dataset without the constant feature. After fitting the model, we'll make predictions and calculate the MSE to evaluate the model's performance.

# %%
# Removing the constant feature from the dataset
X_sample_no_constant = X_sample.drop('constant_feature', axis=1)

# Display the updated DataFrame
X_sample_no_constant.head()
# Out:
#    feature1  feature2  feature3
# 0  0.548814  0.677817  0.311796
# 1  0.715189  0.270008  0.696343
# 2  0.602763  0.735194  0.377752
# 3  0.544883  0.962189  0.179604
# 4  0.423655  0.248753  0.024679

# %%
# Fit the linear regression model without the constant feature
model_sample_no_constant = LinearRegression()
model_sample_no_constant.fit(X_sample_no_constant, y_sample)

# Make predictions and calculate MSE for the new model
predictions_sample_no_constant = model_sample_no_constant.predict(X_sample_no_constant)
mse_sample_no_constant = mean_squared_error(y_sample, predictions_sample_no_constant)

mse_sample_no_constant
# Out:
# 0.24326191926347882

# %% [markdown]
# **Model Performance After Removing Constant Feature**
#
# The Mean Squared Error (MSE) for the model after removing the constant feature is almost identical to the MSE of the model that included the constant feature.
#
# **Conclusion and Interpretation**
#
# The removal of the constant feature did not change the model's performance in terms of MSE. This outcome aligns with our theoretical understanding that a constant feature does not contribute any predictive power to a model. It neither improves nor degrades the model's ability to predict the target variable, as it holds no variance or useful information.

# %% [markdown]
# ## **Dimensionality Reduction:** 🚀📉

# %% [markdown]
# ### **What is curse of dimensionality?**

# %% [markdown]
# The "curse of dimensionality" is a term used in data science and machine learning that describes the problems that arise when analyzing and organizing data in high-dimensional spaces (that is, spaces with many features or variables). It's a bit like trying to find your way in a very, very large and complex maze with many, many paths.
#
# Here's a simple explanation:
#
# 1. **Harder to Visualize:** Just like it's easy to picture a line (1D) or a square (2D), but hard to imagine a 4D or 5D shape, high-dimensional data is very hard for us to visualize or understand.
#
# 2. **More Data Needed:** In high dimensions, the amount of data you need to make good predictions grows exponentially. It's like if you're in a big, multi-level maze, you need many more signs to guide you through it than in a simple one-level maze.
#
# 3. **Distance Measures Become Less Useful:** In high-dimensional spaces, traditional measures of distance (like Euclidean distance) start to become less meaningful. This can make some machine learning algorithms less effective, as they rely on these distance measures.
#
# 4. **Overfitting Risk:** With lots of features, there's a higher chance that your model will start to "memorize" the training data (overfit) rather than learning to generalize from it. It's like focusing too much on the tiny details of the maze and forgetting the overall path to the exit.
#
# 5. **Increased Computational Complexity:** More dimensions mean more calculations for the computer, which can slow down data analysis significantly. Imagine how much longer it would take to solve a maze with hundreds of floors compared to a simple flat one.
#
# In summary, the curse of dimensionality refers to the various issues that arise when dealing with very high-dimensional data. It can make data analysis more complex, less accurate, and more computationally intensive. That's why techniques like feature selection, dimensionality reduction, or choosing appropriate models become critical in high-dimensional settings.

# %% [markdown]
# ### **Why dimensionality reduction is important?**

# %% [markdown]
# Dimensionality reduction techniques are important in data science and machine learning because they help simplify complex datasets. Imagine you have a backpack full of tools, but you're only going on a short hike. Carrying all those tools makes your backpack heavy and your hike more difficult. If you take only what you need, your hike becomes easier and more enjoyable. Dimensionality reduction is like choosing the essential tools for your hike.
#
# Here's why these techniques are necessary:
#
# 1. **Reduces Complexity:** High-dimensional data (data with many features) can be very complex. Reducing dimensions makes the data simpler to work with, just like a lighter backpack is easier to carry.
#
#
# 2. **Improves Model Performance:** Too many features can lead to overfitting, where the model learns the noise in the data rather than the actual trend.
# Reducing dimensions can help the model focus on the most important aspects, just like taking only necessary tools can make your work more efficient.
#
# 3. **Faster Computation:** Fewer dimensions mean fewer calculations, which speeds up data processing and analysis. It's like how a smaller backpack is quicker and easier to pack and carry.
#
# 4. **Easier Visualization and Understanding:** It's hard to visualize and understand data in many dimensions. Reducing dimensions can help you see patterns and relationships more clearly, similar to how a simpler map is easier to read than a complex one.
#
# 5. **Reduces Storage and Memory Needs:** Less dimensional data takes up less space, which can be important for storing and processing large datasets.
#
# 6. **Removes Redundant Features:** Some features may be redundant or irrelevant. Dimensionality reduction helps identify and remove these, making the dataset more effective.
#
# In short, dimensionality reduction helps make large, complex datasets more manageable, understandable, and useful, much like simplifying your gear makes a hike more enjoyable and less burdensome.

# %% [markdown]
# Dimensionality reduction techniques, such as Principal Component Analysis (PCA) or Singular Value Decomposition (SVD), transform the features into a lower-dimensional space while retaining the most important information. It's like condensing our data into a more manageable form without losing too much!

# %% [markdown]
# ### <b>What is PCA?</b>

# %% [markdown]
# In this section, we explore what is perhaps one of the most broadly used of unsupervised algorithms, principal component analysis (PCA). PCA is fundamentally a dimensionality reduction algorithm, but it can also be useful as a tool for visualization, for noise filtering, for feature extraction and engineering, and much more.

# %%
# Sample dataset of student marks in different subjects
np.random.seed(0)  # Seed for reproducibility
student_data = {
    'Math': np.random.randint(50, 100, 5),
    'Physics': np.random.randint(50, 100, 5),
    'Chemistry': np.random.randint(50, 100, 5),
    'Biology': np.random.randint(50, 100, 5),
    'English': np.random.randint(50, 100, 5)
}

student_df = pd.DataFrame(student_data)

# Display the first few rows of the dataframe
student_df.head()
# Out:
#    Math  Physics  Chemistry  Biology  English
# 0    94       89         73       51       74
# 1    97       59         56       88       67
# 2    50       69         74       89       87
# 3    53       71         74       73       75
# 4    53       86         62       96       63

# %% [markdown]
# #### **Let us see how to calculate the Principal Components:**

# %% [markdown]
# **Step 1: Extract a 2x2 Matrix and Standardize the Data**
#
# First, we need to standardize the 2x2 matrix. Let's use the first two rows of "Math" and "Physics" and standardize them.

# %%
# Extracting a 2x2 Matrix (first two rows of the first two features)
data_2x2 = student_df[['Math', 'Physics']].head(2)
data_2x2
# Out:
#    Math  Physics
# 0    94       89
# 1    97       59

# %%
# Plotting the original 2x2 data points (first two rows of Math and Physics)
plt.figure(figsize=(6, 6))
plt.scatter(data_2x2['Math'], data_2x2['Physics'], color='blue', label='Original Data Points')
plt.xlabel('Math Scores')
plt.ylabel('Physics Scores')
plt.title('Original 2x2 Data Points')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# **Plot Interpretation**
#
# The scatter plot above displays the original data points from the first two rows of "Math" and "Physics" scores. Each point represents a student's scores in these two subjects. Since we only have two data points in this example, they are represented as individual points on the plot.

# %%
# Standardizing the 2x2 matrix
scaler_2x2 = StandardScaler()
data_2x2_standardized = scaler_2x2.fit_transform(data_2x2)

# %%
# Plotting the original standardized data points
plt.figure(figsize=(6, 6))
plt.scatter(data_2x2_standardized[:, 0], data_2x2_standardized[:, 1], color='blue', label='Original Data Points')
plt.xlabel('Standardized Math Scores')
plt.ylabel('Standardized Physics Scores')
plt.title('Original Data Points')
plt.axhline(y=0, color='k', linestyle='--', linewidth=1)
plt.axvline(x=0, color='k', linestyle='--', linewidth=1)
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# **Plot: Data Centered at Origin**
#
# The data is already standardized (centered at the origin with unit variance), Standardization involves subtracting the mean and dividing by the standard deviation for each feature, which effectively shifts the data to be centered around the origin.

# %% [markdown]
# **Step 2: Calculate the Covariance Matrix**
#
# For a 2x2 matrix, the covariance matrix is calculated as follows:
#
# 1. Calculate the mean of each feature.
#
# 2. Calculate the covariance for each pair of features. The formula for covariance between two variables X and Y is:
# \begin{align*}
#   Cov(X,Y) &= \frac{1}{n-1}\sum_{i=1}^{n} (X_{i} - \bar X)(Y_{i} - \bar Y) \\
# \end{align*}

# %%
# Calculating the covariance matrix for the standardized 2x2 matrix
covariance_matrix_2x2 = np.cov(data_2x2_standardized)

covariance_matrix_2x2
# Out:
# array([[ 2., -2.],
#        [-2.,  2.]])

# %% [markdown]
# **Step 3: Calculate Eigenvalues and Eigenvectors**
#
# For a 2x2 matrix, we can calculate the eigenvalues (λ) and eigenvectors by solving the characteristic equation:
#
# det(A−λI)=0

# %%
# Calculating eigenvalues and eigenvectors for the 2x2 covariance matrix
eigenvalues_2x2, eigenvectors_2x2 = np.linalg.eig(covariance_matrix_2x2)

eigenvalues_2x2, eigenvectors_2x2
# Out:
# (array([4.0000000e+00, 4.4408921e-16]),
#  array([[ 0.70710678,  0.70710678],
#         [-0.70710678,  0.70710678]]))

# %% [markdown]
# **Interpretation**
#
# Eigenvalues: The first eigenvalue (4.0) is significantly larger than the second (close to 0). This indicates that the first principal component captures most of the variance in the data.
#
# Eigenvectors: These are the principal components. The first eigenvector
#
# [0.7071,0.7071]
#
# [0.7071,0.7071]
#
# is the direction in the feature space along which the data varies the most. The second eigenvector is orthogonal to the first.
#
# **Step 4: Select Principal Components**
#
# In this case, since the first eigenvalue is much larger than the second, we would typically select the first eigenvector as the primary principal component for further analysis. This component captures the majority of the variance in the data.

# %%
# Adding the principal component axes
# Scaling by the square root of eigenvalues to show the amount of variance captured
plt.quiver(0, 0, eigenvectors_2x2[0, 0] * np.sqrt(eigenvalues_2x2[0]), eigenvectors_2x2[1, 0] * np.sqrt(eigenvalues_2x2[0]),
           angles='xy', scale_units='xy', scale=1, color='red', label='PC1')
plt.quiver(0, 0, eigenvectors_2x2[0, 1] * np.sqrt(eigenvalues_2x2[1]), eigenvectors_2x2[1, 1] * np.sqrt(eigenvalues_2x2[1]),
           angles='xy', scale_units='xy', scale=1, color='green', label='PC2')

plt.xlabel('Standardized Math Scores')
plt.ylabel('Standardized Physics Scores')
plt.title('Principal Component Axes')
plt.axhline(y=0, color='k', linestyle='--', linewidth=1)
plt.axvline(x=0, color='k', linestyle='--', linewidth=1)
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# **Plot Interpretation**
#
# In the plot above, the red and green lines represent the first and second principal component axes, respectively. These axes are the directions in which the data varies the most (PC1) and the second most (PC2). The length of each line is proportional to the square root of the corresponding eigenvalue, indicating the amount of variance captured by each principal component.
#
# Red Line (PC1): This is the direction of maximum variance in the data. Since the corresponding eigenvalue is significantly larger, this principal component captures most of the variance in the dataset.
#
# Green Line (PC2): This axis is orthogonal to PC1 and represents the second most significant direction of variance. However, in this specific case, the variance captured by PC2 is almost negligible, as indicated by its very small eigenvalue.

# %% [markdown]
# In the plot above, where we visualized the principal component axes, you observed only the red line (representing PC1) and not the green line (representing PC2). This is likely because the eigenvalue for PC2 is extremely small (close to zero), making the corresponding eigenvector (the green line) very short and hard to see on the plot. This situation is common in PCA when one principal component captures most of the variance in the data.

# %% [markdown]
# ![PCA.png](data:image/png;base64,...)

# %% [markdown]
# **Example:**

# %%
from sklearn.feature_selection import SelectKBest, SelectFromModel, RFE
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %% [markdown]
# **Step 1: Create a Sample Dataset**
#
# Let's start by creating a dataset with student marks in different subjects. We'll simulate this data for demonstration purposes.

# %%
# Sample dataset of student marks in different subjects
np.random.seed(0)  # Seed for reproducibility
student_data = {
    'Math': np.random.randint(50, 100, 5),
    'Physics': np.random.randint(50, 100, 5),
    'Chemistry': np.random.randint(50, 100, 5),
    'Biology': np.random.randint(50, 100, 5),
    'English': np.random.randint(50, 100, 5)
}

student_df = pd.DataFrame(student_data)

# Display the first few rows of the dataframe
student_df.head()
# Out:
#    Math  Physics  Chemistry  Biology  English
# 0    94       89         73       51       74
# 1    97       59         56       88       67
# 2    50       69         74       89       87
# 3    53       71         74       73       75
# 4    53       86         62       96       63

# %% [markdown]
# **Step 2: Standardize the Data**
#
# PCA is sensitive to the variances of the initial variables. Since higher variance variables have a larger effect on the principal components, it's common practice to standardize the data before applying PCA. This will transform our data to have a mean of 0 and a standard deviation of 1 for each feature. Let's standardize our student marks dataset. ​

# %%
from sklearn.preprocessing import StandardScaler

# Standardizing the data
scaler = StandardScaler()
student_df_standardized = scaler.fit_transform(student_df)

# Converting the standardized data into a DataFrame for better readability
student_df_standardized = pd.DataFrame(student_df_standardized, columns=student_df.columns)

# Display the first few rows of the standardized dataframe
student_df_standardized.head()
# Out:
#        Math   Physics  Chemistry   Biology   English
# 0  1.151698  1.270290   0.698884 -1.768655  0.097474
# 1  1.292148 -1.413421  -1.585930  0.535579 -0.755424
# 2 -0.908249 -0.518851   0.833285  0.597855  1.681427
# 3 -0.767798 -0.339937   0.833285 -0.398570  0.219317
# 4 -0.767798  1.001919  -0.779525  1.033791 -1.242794

# %% [markdown]
# **Step 3: Apply PCA**
#
# Now, we'll apply PCA to the standardized data. PCA will transform the original data into a new set of variables, the principal components, which are orthogonal (uncorrelated) and maximize the variance.
#
# We'll start by computing PCA and then analyze the amount of variance captured by each principal component. This will give us insight into how many components we might want to keep. Let's perform PCA using scikit-learn's PCA implementation.

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Applying PCA
pca = PCA()
student_pca = pca.fit_transform(student_df_standardized)

# Convert PCA components to a DataFrame for better readability
student_pca_df = pd.DataFrame(data=student_pca, columns=[f'PC{i+1}' for i in range(len(student_df.columns))])

# Display the first few rows of the PCA components
student_pca_df.head()
# Out:
#         PC1       PC2       PC3       PC4  PC5
# 0 -1.277603  2.211673 -0.085961 -0.187006  0.0
# 1  2.337761  0.200815 -1.238802  0.002444  0.0
# 2 -1.277328 -1.705253 -0.498722 -0.430043  0.0
# 3 -0.923753 -0.477031 -0.033281  0.724161  0.0
# 4  1.140922 -0.230204  1.856765 -0.109555  0.0

# %% [markdown]
# **Step 4: Interpret Results**
#
# The principal components (PCs) are now new features created by PCA. Let's look at how much variance each PC captures. This is important because it tells us how much information from the original data is preserved in each component. We'll plot the explained variance ratio for each principal component. ​

# %%
# Explained variance ratio for each principal component
explained_variance = pca.explained_variance_ratio_

# Plotting the explained variance
plt.figure(figsize=(8, 4))
plt.bar(range(1, len(explained_variance) + 1), explained_variance, alpha=0.7, align='center')
plt.ylabel('Variance Ratio')
plt.xlabel('Principal Component')
plt.title('PCA Explained Variance Ratio')
plt.xticks(range(1, len(explained_variance) + 1))
plt.show()

# %% [markdown]
# **Explained Variance Plot Interpretation**
#
# The bar chart above shows the variance ratio captured by each principal component (PC). The first few PCs capture the most variance, and as we move to higher-numbered PCs, the amount of variance captured decreases.
#
# PC1 captures the most variance, followed by PC2, PC3, and so on.
# The rapid drop in variance captured after the first few PCs suggests that these components contain most of the information in the dataset.

# %%
# Applying PCA with only the first two components
pca_2 = PCA(n_components=2)
student_pca_2 = pca_2.fit_transform(student_df_standardized)

# Shape after reduction
print("Original Shape:", student_df_standardized.shape)
print("Transformed Shape:", student_pca_2.shape)
# Out:
# Original Shape: (5, 5)
# Transformed Shape: (5, 2)

# %% [markdown]
# **Step 5: Visualize the Results**
#
# To better understand the PCA transformation, we can visualize the data in the space of the first two principal components. This will give us a visual sense of how the data is distributed in the reduced dimensionality space. Let's plot the first two principal components.

# %%
# Plotting the first two principal components
plt.figure(figsize=(8, 6))
plt.scatter(student_pca_df['PC1'], student_pca_df['PC2'])
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA on Student Data - First Two Principal Components')
plt.axhline(y=0, color='k', linestyle='--', linewidth=1)
plt.axvline(x=0, color='k', linestyle='--', linewidth=1)
plt.grid(True)
plt.show()

# %% [markdown]
# **PCA Visualization Interpretation**
#
# The scatter plot above shows our student data projected onto the first two principal components (PC1 and PC2). This visualization helps us see the spread and clustering of the data in the reduced-dimensionality space created by PCA.
#
# Axes Represent Principal Components: The x-axis represents the first principal component, and the y-axis represents the second principal component.
#
# Data Spread: The spread of the data points along these axes indicates the variance captured by each principal component. A wider spread along an axis means more variance is captured by that component.
#
# **Conclusion on PCA in This Example**
#
# Dimensionality Reduction: PCA successfully reduced the dimensionality of our data, transforming it into principal components that capture the most significant variance in the data.
#
# Data Visualization: By plotting the first two principal components, we gained insights into the structure of the data that might not be obvious in the higher-dimensional space.
#
# Feature Interpretation: The principal components are linear combinations of the original features. While they are useful for analysis and visualization, their interpretability in terms of the original features may be less straightforward.
# PCA is particularly useful in scenarios with high-dimensional data, enabling simpler models, faster computation, and often better performance by removing noise and redundancy in the data. ​

# %% [markdown]
# ### **Activity 2: True/False**

# %% [markdown]
# 1. **True/False**: PCA can be used to increase the number of features in a dataset for better model performance.
#
# 2. **True/False**: After performing PCA, each principal component is a linear combination of the original features and is orthogonal to the other principal components.
#
# 3. **True/False**: PCA always guarantees improved performance of machine learning models after dimensionality reduction.
#
# 4. **True/False**: Dimensionality reduction using PCA can help in visualizing high-dimensional data by reducing it to two or three dimensions.

# %% [markdown]
# #### **Activity 2 Answers:**

# %% [markdown]
# 1. - **Answer**: False.
#    - **Explanation**: PCA is a dimensionality reduction technique. It reduces the number of features in a dataset by transforming them into principal components. It does not increase the number of features. PCA is used to simplify the dataset while retaining as much information as possible.
#
# 2. - **Answer**: True.
#    - **Explanation**: Each principal component in PCA is indeed a linear combination of the original features. Furthermore, these components are orthogonal to each other, meaning they are uncorrelated. This property ensures that the variance captured by each component is unique.
#
# 3. - **Answer**: False.
#    - **Explanation**: While PCA can help in reducing noise and redundancy in data, it doesn't always guarantee improved performance of machine learning models. The effectiveness of PCA depends on the specific dataset and the model being used. In some cases, important information may be lost during the dimensionality reduction process, potentially leading to poorer model performance.
#
# 4. - **Answer**: True.
#    - **Explanation**: One of the common uses of PCA is to reduce high-dimensional data to two or three dimensions so that it can be visualized in a 2D or 3D plot. This helps in understanding the structure and distribution of the data, although it should be noted that some information is inevitably lost in this reduction process.

# %% [markdown]
# # **✅ Summary ✅**

# %% [markdown]
# ##📚 **What did you learn?** 🤔📖
#
#
# Feature engineering is a crucial process in supervised learning, where the goal is to create new features from existing data to improve model performance and interpretability. It involves transforming raw data into meaningful features that are easier to understand for both humans and machine learning algorithms.
#
# Various companies, such as Amazon, GE Healthcare, PayPal, Spotify, and Tesla, leverage feature engineering for different applications. In finance, feature engineering helps in detecting suspicious patterns for secure transactions, while in education, it personalizes learning experiences for students.
#
# The benefits of feature engineering include preparing datasets compatible with machine learning algorithms and improving model performance. Data scientists spend a significant amount of time on data preparation, making feature engineering an essential part of the data-driven decision-making process.
#
# In the context of machine learning, feature engineering is a fluid and iterative process, with no one-size-fits-all approach. Different machine learning models may require different feature engineering techniques to make data more transparent and interpretable.
#
# The basic exploratory data analysis (EDA) techniques mentioned include univariate analysis, which deals with single variables, and bivariate analysis, which examines the relationship between two sets of values using visualizations like box plots, scatter plots, and violin plots. These analyses help summarize and find patterns in the data, laying the foundation for effective feature engineering and model building.
#
# ## **Best Practices:**
#
# Feature engineering is a crucial step in the data preprocessing phase of building a machine learning model. It involves creating new features or modifying existing ones to improve the performance of the model. Here are some best practices for feature engineering:
#
# 1. **Understand Your Data and Domain**:
#    - Know the context and specifics of your dataset.
#    - Work with domain experts to gain insights that could guide your feature engineering efforts.
#
# 2. **Start with a Clear Objective**:
#    - Identify what you're trying to predict or classify and tailor your features to support this goal.
#    - Ensure that features are relevant to the problem you are solving.
#
# 3. **Keep It Simple**:
#    - Start with simple features before trying complex ones.
#    - Avoid over-engineering, which can lead to overly complex models and overfitting.
#
# 4. **Handle Missing Data Carefully**:
#    - Use strategies like imputation, removal, or indicator variables for missing data.
#    - Understand the implications of each method on your model and data.
#
# 5. **Encode Categorical Variables**:
#    - Convert categorical data into a format that can be easily used by machine learning algorithms (like one-hot encoding or label encoding).
#    - Consider the impact of encoding on dimensionality and model complexity.
#
# 6. **Normalize or Scale Features**:
#    - Apply normalization or scaling when features have different scales or units.
#    - This is especially important for models sensitive to the scale of data like KNN, SVM, and neural networks.
#
# 7. **Feature Selection**:
#    - Use techniques like correlation analysis, backward elimination, or machine learning-based methods to select relevant features.
#    - Avoid including irrelevant or redundant features that can reduce model performance.
#
# 8. **Feature Extraction and Dimensionality Reduction**:
#    - Use techniques like PCA (Principal Component Analysis) to reduce the number of features while retaining important information.
#    - Useful in high-dimensional datasets to combat the curse of dimensionality.
#
# 9. **Temporal and Spatial Feature Engineering**:
#    - For time series or spatial data, create features that capture temporal dynamics (like seasonality, trends) or spatial patterns.
#    - Be mindful of leakage, ensuring that future data is not inadvertently used.
#
# 10. **Iterative Process**:
#     - Treat feature engineering as an iterative process.
#     - Regularly revisit and refine your features based on model performance and new insights.
#
# 11. **Evaluate Feature Importance**:
#     - Use model feedback to understand which features are most important.
#     - This can guide further feature engineering efforts.
#
# 12. **Be Aware of Data Leakage**:
#     - Ensure that your features do not inadvertently include information from the future or from the target variable.
#
# Remember, the most effective feature engineering strategies often depend on the specific characteristics of the dataset and the problem at hand. Regular experimentation and validation are key to identifying the most impactful features.
#
# ## **Shortcomings:**
#
# Feature engineering, while essential in machine learning, comes with its own set of challenges and limitations. Understanding these shortcomings is important for effective model development. Here are some key ones:
#
# 1. **Time-Consuming Process**:
#    - Feature engineering often requires a significant amount of time and effort. It involves understanding the data deeply, creating hypotheses, and iteratively testing them.
#
# 2. **Requires Domain Expertise**:
#    - Effective feature engineering often relies on domain knowledge to create meaningful features. Lack of such knowledge can lead to the omission of important features or the creation of irrelevant ones.
#
# 3. **Risk of Overfitting**:
#    - Over-engineering features can lead to models that are too complex and fit too closely to the training data, performing poorly on unseen data (overfitting).
#
# 4. **Model Complexity**:
#    - Adding too many features, or overly complex features, can increase the complexity of the model. This might make the model harder to understand and interpret.
#
# 5. **Data Leakage**:
#    - There's a risk of accidentally introducing information about the target variable into the features, a problem known as data leakage, which can lead to overly optimistic performance estimates.
#
# 6. **Scalability Issues**:
#    - Some feature engineering techniques may not scale well with large datasets, either due to computational constraints or because they rely on fine-tuned manual processes.
#
# 7. **Dynamic Data Changes**:
#    - Features engineered based on historical data may become irrelevant or misleading if the underlying data distribution changes over time (concept drift).
#
# 8. **Bias Amplification**:
#    - If the original data contains biases, feature engineering can inadvertently amplify these biases, leading to unfair or biased model predictions.
#
# 9. **Dependency on Quality of Data**:
#    - The effectiveness of feature engineering is heavily dependent on the quality of the underlying data. Poor quality data (noisy, erroneous, or incomplete) can severely limit the potential gains from feature engineering.
#
# 10. **Difficulty in Automation**:
#     - While some aspects of feature engineering can be automated, many require creative and iterative human input, making full automation challenging.
#
# Despite these challenges, feature engineering remains a critical step in building effective machine learning models. The key is to be aware of these pitfalls and approach feature engineering with a careful, informed strategy.

# %% [markdown]
# #**🧠Enhance Your Knowledge🧠**

# %% [markdown]
# ## **Additional Reading:**

# %% [markdown]
# ### **Handling Missing Values and Outliers:**

# %% [markdown]
# #### **1.	Mean/ Median/Mode Replacement**

# %% [markdown]
# We will solve this by replacing the missing value with either mean/median/mode. In the case of the categorical variables, we can use mode.

# %%
# Handle missing values
def handle_missing_values(data):
    # Impute missing values for 'Age' with median
    data['Age'].fillna(data['Age'].median(), inplace=True)

    # Impute missing values for 'Embarked' with mode
    data['Embarked'].fillna(data['Embarked'].mode()[0], inplace=True)

    # Drop 'Cabin' column due to a high number of missing values
    data.drop(columns=['Cabin'], inplace=True)

    return data.isnull().sum()

# %%
# Handling missing values using the function created
handle_missing_values(titanic_data)
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
titanic_data.shape
# Out:
# (891, 11)

# %% [markdown]
# #### **2.	Imputing Random Values**

# %% [markdown]
# Random Value imputation consists of taking random observation from the dataset and we can use this observation to replace the missing value.

# %%
import pandas as pd
import numpy as np

# Define a function to impute random values for missing entries
def impute_random_values(df, column):
    # Identify missing indices
    missing_indices = df[df[column].isnull()].index

    # Calculate the mean and standard deviation of the column
    column_mean = df[column].mean()
    column_std = df[column].std()

    # Generate random values with mean and std deviation
    random_values = np.random.normal(column_mean, column_std, len(missing_indices))

    # Update missing values with random values
    df.loc[missing_indices, column] = random_values

    return df

# %%
# Create a sample DataFrame
data = {
    'Age': [25, 30, np.nan, 22, 28, np.nan, 35, 40, 29, np.nan],
    'Salary': [50000, 60000, 55000, np.nan, 75000, np.nan, 80000, np.nan, 70000, 72000]
}

df = pd.DataFrame(data)
# Display the original DataFrame
print("Original DataFrame:")
print(df)
# Out:
# Original DataFrame:
#     Age   Salary
# 0  25.0  50000.0
# 1  30.0  60000.0
# 2   NaN  55000.0
# 3  22.0      NaN
# 4  28.0  75000.0
# 5   NaN      NaN
# 6  35.0  80000.0
# 7  40.0      NaN
# 8  29.0  70000.0
# 9   NaN  72000.0

# %%
# Impute random values for missing entries in 'Age' and 'Salary'
df = impute_random_values(df, 'Age')
df = impute_random_values(df, 'Salary')

# Display the DataFrame after imputation
print("\nDataFrame after random imputation:")
print(df)
# Out:
# DataFrame after random imputation:
#          Age        Salary
# 0  25.000000  50000.000000
# 1  30.000000  60000.000000
# 2  28.904905  55000.000000
# 3  22.000000  76489.579512
# 4  28.000000  75000.000000
# 5  43.486742  74309.146384
# 6  35.000000  80000.000000
# 7  40.000000  52778.276341
# 8  29.000000  70000.000000
# 9  25.601069  72000.000000

# %% [markdown]
# #### **3.	Imputing Arbitrary Values**

# %% [markdown]
# Arbitrary Value imputation consists of taking arbitrary value outside of the dataset and we can use that value to replace the missing value.

# %%
import pandas as pd
import numpy as np

# Create a sample DataFrame with missing values
data = pd.DataFrame({
    'Age': [25, np.nan, 30, 22, np.nan, 40, 28, np.nan, 35],
    'Income': [50000, 60000, 75000, np.nan, 45000, np.nan, 70000, 55000, 80000]
})

print("Original data:")
print(data)
# Out:
# Original data:
#     Age   Income
# 0  25.0  50000.0
# 1   NaN  60000.0
# 2  30.0  75000.0
# 3  22.0      NaN
# 4   NaN  45000.0
# 5  40.0      NaN
# 6  28.0  70000.0
# 7   NaN  55000.0
# 8  35.0  80000.0

# %%
# Define a function to impute missing values with an arbitrary value
def impute_arbitrary_value(data, column_name, arbitrary_value):
    data[column_name].fillna(arbitrary_value, inplace=True)
    return data

# %%
# Impute missing values with an arbitrary value
imputed_data = impute_arbitrary_value(data, 'Age', 99)
imputed_data = impute_arbitrary_value(imputed_data, 'Income', 0)

print("\nData after imputation:")
print(imputed_data)
# Out:
# Data after imputation:
#     Age   Income
# 0  25.0  50000.0
# 1  99.0  60000.0
# 2  30.0  75000.0
# 3  22.0      0.0
# 4  99.0  45000.0
# 5  40.0      0.0
# 6  28.0  70000.0
# 7  99.0  55000.0
# 8  35.0  80000.0

# %% [markdown]
# #### **4.	Creating a new feature using  NaN values or changing existing  NaN  with other values**

# %% [markdown]
# Say there is a feature named Age, and some of the values are missing. Thus, we can create another feature while replacing NaN with 1 and non-NaN with 0.

# %%
import pandas as pd
import numpy as np

# Create a sample DataFrame with missing values
data = pd.DataFrame({
    'Age': [25, np.nan, 30, 22, np.nan, 40, 28, np.nan, 35],
    'Income': [50000, 60000, 75000, np.nan, 45000, np.nan, 70000, 55000, 80000]
})

print("Original data:")
print(data)

# Define a function to create a new feature based on the presence of NaN values
def create_nan_feature(data, column_name):
    new_column_name = column_name + '_has_nan'
    data[new_column_name] = data[column_name].isnull().astype(int)
    return data

# Define a function to replace NaN values with a specified value
def replace_nan_with_value(data, column_name, replacement_value):
    data[column_name].fillna(replacement_value, inplace=True)
    return data

# Create a new feature indicating presence of NaN in 'Age' column
data_with_nan_feature = create_nan_feature(data, 'Age')

# Replace NaN values in 'Income' column with 0
data_replaced_nan = replace_nan_with_value(data_with_nan_feature, 'Income', 0)

print("\nData after creating new feature and replacing NaN values for income column :")
print(data_replaced_nan)
# Out:
# Original data:
#     Age   Income
# 0  25.0  50000.0
# 1   NaN  60000.0
# 2  30.0  75000.0
# 3  22.0      NaN
# 4   NaN  45000.0
# 5  40.0      NaN
# 6  28.0  70000.0
# 7   NaN  55000.0
# 8  35.0  80000.0
#
# Data after creating new feature and replacing NaN values for income column :
#     Age   Income  Age_has_nan
# 0  25.0  50000.0            0
# 1   NaN  60000.0            1
# 2  30.0  75000.0            0
# 3  22.0      0.0            0
# 4   NaN  45000.0            1
# 5  40.0      0.0            0
# 6  28.0  70000.0            0
# 7   NaN  55000.0            1
# 8  35.0  80000.0            0

# %% [markdown]
# #### **5.	End of Distribution Imputation**

# %% [markdown]
# If there is suspicion that the missing value is not at random then capturing that information is important. In this scenario, one would want to replace missing data with values that are at the tails of the distribution of the variable. The advantage is that it is quick and captures the importance of missing values (if one suspects the missing data is valuable).

# %%
import pandas as pd
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt

# Create a sample DataFrame with missing values
data = pd.DataFrame({
    'Age': [25, np.nan, 30, 22, np.nan, 40, 28, np.nan, 35],
    'Income': [50000, 60000, 75000, np.nan, 45000, np.nan, 70000, 55000, 80000]
})

print("Original data:")
print(data)

# Define a function for end-of-distribution imputation
def end_of_distribution_imputation(data, column_name):
    std_dev = data[column_name].std()
    mean = data[column_name].mean()
    extreme_value = mean + (3 * std_dev)  # 3 standard deviations above the mean

    data[column_name].fillna(extreme_value, inplace=True)
    return data

# Impute missing values using end-of-distribution approach
imputed_data = end_of_distribution_imputation(data, 'Age')
imputed_data = end_of_distribution_imputation(imputed_data, 'Income')

print("\nData after end-of-distribution imputation:")
print(imputed_data)
# Out:
# Original data:
#     Age   Income
# 0  25.0  50000.0
# 1   NaN  60000.0
# 2  30.0  75000.0
# 3  22.0      NaN
# 4   NaN  45000.0
# 5  40.0      NaN
# 6  28.0  70000.0
# 7   NaN  55000.0
# 8  35.0  80000.0
#
# Data after end-of-distribution imputation:
#          Age         Income
# 0  25.000000   50000.000000
# 1  49.809089   60000.000000
# 2  30.000000   75000.000000
# 3  22.000000  101693.909143
# 4  49.809089   45000.000000
# 5  40.000000  101693.909143
# 6  28.000000   70000.000000
# 7  49.809089   55000.000000
# 8  35.000000   80000.000000

# %% [markdown]
# #### **6.	Frequent Categories Imputation**

# %% [markdown]
# It is used where a very less number of missing values are present and for categorical variables. It’s also known as the mode imputation. It’s easy and fast to implement.

# %%
import pandas as pd
import numpy as np

# Create a sample DataFrame with a categorical column containing missing values
data = pd.DataFrame({
    'Gender': ['Male', 'Female', 'Male', np.nan, 'Female', 'Female', np.nan, 'Male', 'Male']
})

print("Original data:")
print(data)
# Out:
# Original data:
#    Gender
# 0    Male
# 1  Female
# 2    Male
# 3     NaN
# 4  Female
# 5  Female
# 6     NaN
# 7    Male
# 8    Male

# %%
# Define a function for frequent categories imputation
def frequent_categories_imputation(data, column_name):
    most_frequent_category = data[column_name].mode()[0]
    data[column_name].fillna(most_frequent_category, inplace=True)
    return data

# %%
# Impute missing values using frequent categories approach
imputed_data = frequent_categories_imputation(data, 'Gender')

print("\nData after frequent categories imputation:")
print(imputed_data)
# Out:
# Data after frequent categories imputation:
#    Gender
# 0    Male
# 1  Female
# 2    Male
# 3    Male
# 4  Female
# 5  Female
# 6    Male
# 7    Male
# 8    Male

# %% [markdown]
# #### **7.	Deleting Column if Missing Value >60%**

# %% [markdown]
# If the complete row is having NaN values then it doesn’t make any sense/value out of it. So such rows/columns are to be dropped immediately. Or if the % of row/column is mostly missing say about more than 60% then also we can choose to drop.

# %%
import pandas as pd
import numpy as np

# Create a sample DataFrame with missing values
data = pd.DataFrame({
    'Age': [25, np.nan, np.nan, 22, np.nan, np.nan, np.nan, np.nan, 35],
    'Income': [50000, 75000, np.nan, np.nan, 45000, np.nan, 70000, 55000, 80000],
    'Education': [np.nan, 'Bachelor', 'Master', 'PhD', 'Bachelor', 'PhD', 'Master', np.nan, 'Bachelor']
})

print("Original data:")
print(data)
# Out:
# Original data:
#     Age   Income Education
# 0  25.0  50000.0       NaN
# 1   NaN  75000.0  Bachelor
# 2   NaN      NaN    Master
# 3  22.0      NaN       PhD
# 4   NaN  45000.0  Bachelor
# 5   NaN      NaN       PhD
# 6   NaN  70000.0    Master
# 7   NaN  55000.0       NaN
# 8  35.0  80000.0  Bachelor

# %%
# Define a function to delete columns with missing values > 60%
def delete_columns_with_high_missing(data, threshold):
    columns_to_delete = data.columns[data.isnull().mean() > threshold]
    data.drop(columns=columns_to_delete, inplace=True)
    return data

# %%
# Delete columns with missing values > 60%
threshold = 0.6
data_after_deletion = delete_columns_with_high_missing(data, threshold)

print("\nData after deleting columns with missing values > 60%:")
print(data_after_deletion)
# Out:
# Data after deleting columns with missing values > 60%:
#     Income Education
# 0  50000.0       NaN
# 1  75000.0  Bachelor
# 2      NaN    Master
# 3      NaN       PhD
# 4  45000.0  Bachelor
# 5      NaN       PhD
# 6  70000.0    Master
# 7  55000.0       NaN
# 8  80000.0  Bachelor

# %% [markdown]
# #### **8.	Creating a Sub-model to predict the missing value**

# %% [markdown]
# Here, we will create a sub-model while taking the non-missing value as a separate dataset(we will split and create a model with this dataset) and the missing value as another dataset whose values are to be predicted.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# Create a sample DataFrame with missing ages
data = pd.DataFrame({
    'Pclass': [1, 3, 2, 1, 3, 2, 1, 2, 3],
    'Fare': [71.2833, 7.925, 11.5, 53.1, 8.05, 21.075, 263, 7.925, 8.05],
    'Age': [38, np.nan, 26, 35, np.nan, 28, 35, np.nan, 24]
})

print("Original data:")
print(data)

# Separate data into features (X) and target (y) for training the sub-model
X = data.drop(columns='Age')
y = data['Age']

# Separate the data with non-missing ages for training
X_train = X[~y.isnull()]
y_train = y[~y.isnull()]

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# Train a simple linear regression model
sub_model = LinearRegression()
sub_model.fit(X_train, y_train)

# Predict missing ages using the trained sub-model
predicted_ages = sub_model.predict(X_test)

# Impute missing ages with predicted values
data.loc[data['Age'].isnull(), 'Age'] = sub_model.predict(X[data['Age'].isnull()])

print("\nData after using a sub-model to predict missing ages:")
print(data)
# Out:
# Original data:
#    Pclass      Fare   Age
# 0       1   71.2833  38.0
# 1       3    7.9250   NaN
# 2       2   11.5000  26.0
# 3       1   53.1000  35.0
# 4       3    8.0500   NaN
# 5       2   21.0750  28.0
# 6       1  263.0000  35.0
# 7       2    7.9250   NaN
# 8       3    8.0500  24.0
#
# Data after using a sub-model to predict missing ages:
#    Pclass      Fare        Age
# 0       1   71.2833  38.000000
# 1       3    7.9250  23.515588
# 2       2   11.5000  26.000000
# 3       1   53.1000  35.000000
# 4       3    8.0500  23.515928
# 5       2   21.0750  28.000000
# 6       1  263.0000  35.000000
# 7       2    7.9250  28.932327
# 8       3    8.0500  24.000000

# %% [markdown]
# #### **9.	Use Algorithms that support Missing Values**

# %% [markdown]
# KNN is a machine learning algorithm that works on the principle of distance measure. This algorithm can be used when there are nulls present in the dataset. While the algorithm is applied, KNN considers the missing values by taking the majority of the K nearest values.
#
# Another algorithm that can be used here is Random Forest. This model produces a robust result because it works well on non-linear and categorical data. It adapts to the data structure taking into consideration of the high variance or the bias, producing better results on large datasets.
#
# Generally Tree based models can work with missing values.

# %%
import pandas as pd
import numpy as np
from sklearn.impute import KNNImputer

# Create a sample DataFrame with missing values
data = pd.DataFrame({
    'Age': [25, 30, np.nan, 22, np.nan, 40, 28, np.nan, 35],
    'Income': [50000, 75000, np.nan, np.nan, 45000, np.nan, 70000, 55000, 80000],
})

print("Original data:")
print(data)

# Create a KNNImputer instance
knn_imputer = KNNImputer(n_neighbors=2)

# Impute missing values using KNN
imputed_data = knn_imputer.fit_transform(data)

# Convert the imputed array back to a DataFrame
imputed_data_df = pd.DataFrame(imputed_data, columns=data.columns)

print("\nData after KNN imputation:")
print(imputed_data_df)
# Out:
# Original data:
#     Age   Income
# 0  25.0  50000.0
# 1  30.0  75000.0
# 2   NaN      NaN
# 3  22.0      NaN
# 4   NaN  45000.0
# 5  40.0      NaN
# 6  28.0  70000.0
# 7   NaN  55000.0
# 8  35.0  80000.0
#
# Data after KNN imputation:
#     Age   Income
# 0  25.0  50000.0
# 1  30.0  75000.0
# 2  30.0  62500.0
# 3  22.0  60000.0
# 4  26.5  45000.0
# 5  40.0  77500.0
# 6  28.0  70000.0
# 7  26.5  55000.0
# 8  35.0  80000.0

# %% [markdown]
# #### **1. Using Standard Deviation in Symmetric Curve**

# %% [markdown]
# The standard deviation is a measure of how spread out the values in a dataset are around the mean. The idea behind using standard deviation for outlier detection is that data points that are significantly far from the mean are considered outliers.
#
# **Here's how it works:**
#
# - Calculate Mean and Standard Deviation: Calculate the mean (average) and standard deviation of the dataset.
#
# - Define Threshold: Determine a threshold value (often denoted as k) that represents how many standard deviations away from the mean a value must be in order to be considered an outlier. Generally if any data point lies 3 standard deviations away from the mean we can say that data point is an outlier.
#
# - Detect Outliers: Any data point whose value is more than k times the standard deviation away from the mean can be classified as an outlier. This can be determined using the formula: value > mean + k * std_dev or value < mean - k * std_dev.
#
# - Outlier Treatment using Standard Deviation: Once outliers are detected, they can be treated using various methods. One common approach is to cap or clip the outlier values to a certain range, which can be determined based on the mean and standard deviation.

# %%
import pandas as pd
import numpy as np

# Create a sample DataFrame with a symmetric distribution and outliers
data = pd.DataFrame({
    'Value': [20, 21, 19, 25, 24, 22, 23, 18, 30, 27, 26, 28, 100]
})

print("Original data:")
print(data)
# Out:
# Original data:
#     Value
# 0      20
# 1      21
# 2      19
# 3      25
# 4      24
# 5      22
# 6      23
# 7      18
# 8      30
# 9      27
# 10     26
# 11     28
# 12    100

# %%
# Calculate mean and standard deviation
mean = data['Value'].mean()
std_dev = data['Value'].std()

print("Mean of the data: ", mean)
print("Standard deviation of the data: ", std_dev)
# Out:
# Mean of the data:  29.46153846153846
# Standard deviation of the data:  21.496570984753923

# %%
# Detect outliers using standard deviation
std_dev_threshold = 3
lower_bound = mean - std_dev_threshold * std_dev
upper_bound = mean + std_dev_threshold * std_dev
outliers = data[(data['Value'] < lower_bound) | (data['Value'] > upper_bound)]

print("\nOutliers detected using standard deviation:")
print(outliers)
# Out:
# Outliers detected using standard deviation:
#     Value
# 12    100

# %%
# Define a function to treat outliers using standard deviation
def treat_outliers_std(data, column_name, std_dev_threshold):
    lower_bound = mean - std_dev_threshold * std_dev
    upper_bound = mean + std_dev_threshold * std_dev
    data[column_name] = np.clip(data[column_name], lower_bound, upper_bound)
    return data

# Treat outliers using standard deviation
data_treated = treat_outliers_std(data.copy(), 'Value', std_dev_threshold)

print("\nData after outlier treatment using standard deviation:")
print(data_treated)
# Out:
# Data after outlier treatment using standard deviation:
#         Value
# 0   20.000000
# 1   21.000000
# 2   19.000000
# 3   25.000000
# 4   24.000000
# 5   22.000000
# 6   23.000000
# 7   18.000000
# 8   30.000000
# 9   27.000000
# 10  26.000000
# 11  28.000000
# 12  93.951251

# %% [markdown]
# Using the standard deviation for outlier detection and treatment assumes that the data is approximately normally distributed (symmetric). It's a simple and intuitive method, but it might not be suitable for all types of data distributions. Additionally, the choice of the threshold value (k) requires careful consideration to balance between sensitivity to outliers and preserving data integrity.
#
# Remember that outlier treatment should be done thoughtfully and in line with the characteristics of your data and the goals of your analysis.

# %% [markdown]
# #### **2. Using IQR in Skew-symmetric Curve**

# %% [markdown]
# The box plot is a useful graphical display for describing the behavior of the data in the middle as well as at the ends of the distributions. The box plot uses the median and the lower and upper quartiles (defined as the 25th and 75th percentiles). If the lower quartile is Q1 and the upper quartile is Q3, then the difference (Q3 — Q1) is called the interquartile range or IQR.
#
# A box plot is constructed by drawing a box between the upper and lower quartiles with a solid line drawn across the box to locate the median. The following quantities (called fences) are needed for identifying extreme values in the tails of the distribution:
#
# 1.	lower inner fence: Q1–1.5*IQ
# 2.	upper inner fence: Q3 + 1.5*IQ
# 3.	lower outer fence: Q1–3*IQ
# 4.	upper outer fence: Q3 + 3*IQ

# %%
import pandas as pd
import numpy as np

# Create a sample DataFrame with a skew-symmetric distribution and outliers
data = pd.DataFrame({
    'Value': [10, 12, 13, 15, 16, 17, 18, 19, 20, 22, 23, 24, 100]
})

print("Original data:")
print(data)
# Out:
# Original data:
#     Value
# 0      10
# 1      12
# 2      13
# 3      15
# 4      16
# 5      17
# 6      18
# 7      19
# 8      20
# 9      22
# 10     23
# 11     24
# 12    100

# %%
# Calculate the first quartile (Q1) and third quartile (Q3)
q1 = data['Value'].quantile(0.25)
q3 = data['Value'].quantile(0.75)

# Calculate the Interquartile Range (IQR)
iqr = q3 - q1

# Detect outliers using IQR
iqr_multiplier = 1.5
lower_bound = q1 - iqr_multiplier * iqr
upper_bound = q3 + iqr_multiplier * iqr
outliers = data[(data['Value'] < lower_bound) | (data['Value'] > upper_bound)]

print("\nOutliers detected using IQR:")
print(outliers)
# Out:
# Outliers detected using IQR:
#     Value
# 12    100

# %%
# Define a function to treat outliers using IQR
def treat_outliers_iqr(data, column_name, iqr_multiplier):
    lower_bound = q1 - iqr_multiplier * iqr
    upper_bound = q3 + iqr_multiplier * iqr
    data[column_name] = np.clip(data[column_name], lower_bound, upper_bound)
    return data

# Treat outliers using IQR
data_treated = treat_outliers_iqr(data.copy(), 'Value', iqr_multiplier)

print("\nData after outlier treatment using IQR:")
print(data_treated)
# Out:
# Data after outlier treatment using IQR:
#     Value
# 0    10.0
# 1    12.0
# 2    13.0
# 3    15.0
# 4    16.0
# 5    17.0
# 6    18.0
# 7    19.0
# 8    20.0
# 9    22.0
# 10   23.0
# 11   24.0
# 12   32.5

# %% [markdown]
# ### **Categorical Encoding**

# %% [markdown]
# This means that categorical data must be encoded into numbers before we can use it to fit and evaluate a model. There are many ways to encode categorical variables for modeling as follows.

# %% [markdown]
# #### **1.Nominal Encoding**

# %% [markdown]
# Variable comprises a finite set of discrete values with no relationship between values. Some examples include:
#
# •	A “pet” variable with the values: “dog” and “cat“.
#
# •	A “color” variable with the values: “red“, “green“, and “blue“.
#
# •	A “place” variable with the values: “first“, “second“, and “third“

# %% [markdown]
# **1.	One Hot Encoding**

# %% [markdown]
# One-hot encoding, also known as dummy coding, is a technique where each category is transformed into a binary column. Each category becomes a new binary column, and the presence of the category is indicated by a 1, while other columns remain 0. This approach is suitable when the categorical variable has no ordinal relationship.
#
# **Example:**
#
# Suppose you have a categorical variable "Color" with categories "Red," "Blue," and "Green." One-hot encoding transforms these categories into binary columns as follows:
#
# | Color | Red | Blue | Green |
# |-------|-----|------|-------|
# | Red   | 1   | 0    | 0     |
# | Blue  | 0   | 1    | 0     |
# | Green | 0   | 0    | 1     |
#
# In this example, each category "Red," "Blue," and "Green" has been transformed into its own binary column, indicating its presence or absence in each row of the dataset.

# %% [markdown]
# **2.	One Hot Encoding with many  Categorical**
#
# When dealing with datasets that have multiple categorical variables, you might encounter scenarios where you need to apply one-hot encoding to all of these variables. One-hot encoding individually for each variable creates binary columns for each category, indicating its presence or absence. It is the same as one-hot encoding but the difference is Let you have more than 20 unique categories. Then if you will perform one-hot encoding to all those you will have additional 20 columns. This will lead to the Curse of Dimensionality. So, It has been observed from the KDD Orange Cup challenge that some top n no. of maximum categories are taken and encoded.
#
# **Example:**
#
# Suppose you have a dataset with two categorical variables, "Color" and "Size." The categories for each variable are as follows:
#
# | Color  | Size   |
# |--------|--------|
# | Red    | Small  |
# | Blue   | Medium |
# | Green  | Large  |
#
# After applying one-hot encoding, the categorical variables are transformed into binary columns as shown below:
#
# **Encoded Values:**
#
# | Color | Red | Blue | Green | Size   | Small | Medium | Large |
# |-------|-----|------|-------|--------|-------|--------|-------|
# | Red   | 1   | 0    | 0     | Small  | 1     | 0      | 0     |
# | Blue  | 0   | 1    | 0     | Medium | 0     | 1      | 0     |
# | Green | 0   | 0    | 1     | Large  | 0     | 0      | 1     |
#
# Each categorical variable has been transformed into separate binary columns, capturing the presence or absence of each category in the dataset. This expanded representation is helpful for machine learning algorithms to understand the categorical information.

# %% [markdown]
# **3. Mean Encoding (Target Encoding)**
#
# Mean Encoding, also known as Target Encoding, is a technique used to transform categorical variables into a numeric format based on the mean (or other statistical metrics) of the target variable for each category. This technique is particularly useful when dealing with categorical variables in regression or classification tasks.
#
# **How it Works:**
#
# 1. **Calculate the Mean for Each Category:**
#    - For each category in the categorical variable, calculate the mean of the target variable for the samples that belong to that category.
#
# 2. **Replace Categories with Mean Values:**
#    - Replace the original category labels with the corresponding mean values calculated in the previous step.
#
# **Example:**
#
# Suppose you have a dataset with a categorical variable "Color" and a target variable "Price." The "Color" variable has categories "Red," "Blue," and "Green," and the target variable "Price" contains the prices of products. The mean encoding process would look like this:
#
# | Color  | Price in Dollars |
# |--------|-------|
# | Red    | 100  |
# | Blue   | 150  |
# | Green  | 120  |
# | Blue   | 160  |
# | Red    | 110  |
#
# **Encoded Values:**
#
# | Color  | Encoded Price Mean |
# |--------|---------------------|
# | Red    | 105                |
# | Blue   | 155                |
# | Green  | 120                |
# | Blue   | 155                |
# | Red    | 105                |
#
# In this example, the original "Color" categories are replaced with the mean prices of products that belong to each category. The mean encoding provides a way to incorporate categorical information into your models while leveraging the relationship between categories and the target variable.

# %% [markdown]
# #### **2. Ordinal Encoding**

# %% [markdown]
# Variable comprises a finite set of discrete values with a ranked ordering between values. In ordinal encoding, each unique category value is assigned an integer value.
#
# For example, “red” is 1, “green” is 2, and “blue” is 3.

# %% [markdown]
# **1. Label Encoding**
#
#
# Label Encoding is a technique used to convert categorical variables into numerical format. In this method, each unique category is assigned a unique integer value. This technique is suitable when the categorical variable has an ordinal relationship or when working with algorithms that require numeric input.
#
# **How it Works:**
#
# 1. **Assign Integer Labels:**
#    - For each unique category in the categorical variable, assign a unique integer label starting from 0 or 1.
#
# 2. **Replace Categories with Labels:**
#    - Replace the original category labels with the corresponding integer labels assigned in the previous step.
#
# **Example:**
#
# Suppose you have a dataset with a categorical variable "Size," which has categories "Small," "Medium," and "Large." The label encoding process would look like this:
#
# | Size    |
# |---------|
# | Medium  |
# | Small   |
# | Large   |
# | Medium  |
# | Small   |
#
# **Encoded Values:**
#
# | Size    | Encoded Label |
# |---------|---------------|
# | Medium  | 1             |
# | Small   | 0             |
# | Large   | 2             |
# | Medium  | 1             |
# | Small   | 0             |
#
# In this example, the original "Size" categories are replaced with integer labels. Label Encoding is simple to implement and can work well with algorithms that understand numeric values. However, it's important to note that some algorithms might misinterpret the numeric labels as having ordinal relationships, even when they don't exist.

# %%
#Example Code
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Create a sample DataFrame with a categorical variable
data = pd.DataFrame({
    'Size': ['Medium', 'Small', 'Large', 'Medium', 'Small']
})

print("Original data:")
print(data)

# Initialize LabelEncoder
encoder = LabelEncoder()

# Fit and transform the encoder on the categorical variable
encoded_data = encoder.fit_transform(data['Size'])

# Create a new column with the encoded values
data['Encoded_Size'] = encoded_data

print("\nEncoded data:")
print(data)
# Out:
# Original data:
#      Size
# 0  Medium
# 1   Small
# 2   Large
# 3  Medium
# 4   Small
#
# Encoded data:
#      Size  Encoded_Size
# 0  Medium             1
# 1   Small             2
# 2   Large             0
# 3  Medium             1
# 4   Small             2

# %% [markdown]
# **2. Target Guided Ordinal Encoding**

# %% [markdown]
# Target Guided Ordinal Encoding is a technique used to convert categorical variables into numerical format while considering the relationship between the categories and the target variable. It assigns labels to categories based on the mean of the target variable for each category. This method is especially useful when the categorical variable exhibits a clear ordinal relationship with the target variable.so, in other words, “target guided ordinal encoding = mean encoding +label encoding.”
#
# **How it Works:**
#
# 1. **Calculate Mean Target for Each Category:**
#    - For each category in the categorical variable, calculate the mean of the target variable for the samples that belong to that category.
#
# 2. **Assign Labels Based on Mean Target:**
#    - Assign labels to categories in ascending order of their mean target values. Categories with higher mean target values receive higher labels.
#
# **Example:**
#
# Suppose you have a dataset with a categorical variable "Education" and a target variable "Income." The "Education" variable has categories "Bachelor," "Master," and "PhD," and the target variable "Income" represents income levels. The target guided ordinal encoding process would look like this:
#
# | Education | Income |
# |-----------|--------|
# | Bachelor  | 50000 |
# | Master    | 75000 |
# | PhD       | 60000 |
# | Bachelor  | 55000 |
# | PhD       | 70000 |
#
# **Encoded Values:**
#
# | Education | Encoded Education |
# |-----------|-------------------|
# | Bachelor  | 1                 |
# | Master    | 2                 |
# | PhD       | 3                 |
# | Bachelor  | 1                 |
# | PhD       | 3                 |
#
# In this example, the "Education" categories are assigned labels based on their mean income levels. "Bachelor" is assigned the lowest label (1) since it has the lowest mean income, while "PhD" is assigned the highest label (3) due to its higher mean income. Target guided ordinal encoding leverages the relationship between categories and the target variable, making it suitable for ordinal categorical variables.

# %%
import pandas as pd

# Create a sample DataFrame with categorical variable and target variable
data = pd.DataFrame({
    'Education': ['Bachelor', 'Master', 'PhD', 'Bachelor', 'PhD'],
    'Income': [50000, 75000, 60000, 55000, 70000]
})

print("Original data:")
print(data)

# Calculate mean income for each education level
mean_income_by_education = data.groupby('Education')['Income'].mean().sort_values()

# Create a dictionary to map education levels to labels based on mean income
education_labels = {education: label + 1 for label, education in enumerate(mean_income_by_education.index)}

# Apply target guided ordinal encoding
data['Encoded_Education'] = data['Education'].map(education_labels)

print("\nEncoded data:")
print(data)
# Out:
# Original data:
#   Education  Income
# 0  Bachelor   50000
# 1    Master   75000
# 2       PhD   60000
# 3  Bachelor   55000
# 4       PhD   70000
#
# Encoded data:
#   Education  Income  Encoded_Education
# 0  Bachelor   50000                  1
# 1    Master   75000                  3
# 2       PhD   60000                  2
# 3  Bachelor   55000                  1
# 4       PhD   70000                  2

# %% [markdown]
# **3.	Count or Frequency Encoding**

# %% [markdown]
# Count or Frequency Encoding is a technique used to convert categorical variables into numerical format based on the frequency or count of each category in the dataset. It assigns labels to categories based on how often each category appears. This method is suitable when the categorical variable doesn't have an ordinal relationship and when you want to capture the prevalence of each category.
#
# **How it Works:**
#
# 1. **Calculate Frequency of Each Category:**
#    - For each category in the categorical variable, calculate the frequency or count of how many times the category appears in the dataset.
#
# 2. **Assign Labels Based on Frequency:**
#    - Assign labels to categories based on their frequency in ascending or descending order. Categories with higher frequencies receive higher labels.
#
# **Example:**
#
# Suppose you have a dataset with a categorical variable "Color." The "Color" variable has categories "Red," "Blue," and "Green." The count or frequency encoding process would look like this:
#
# | Color  |
# |--------|
# | Red    |
# | Blue   |
# | Green  |
# | Blue   |
# | Red    |
#
# **Encoded Values:**
#
# | Color  | Encoded Color |
# |--------|---------------|
# | Red    | 2             |
# | Blue   | 2             |
# | Green  | 1             |
# | Blue   | 2             |
# | Red    | 2             |
#
# In this example, the "Color" categories are assigned labels based on their frequency. "Blue" appears the most frequently (count = 3), so it receives the highest label (2), while "Green" appears the least frequently (count = 1) and gets the lowest label (1). Count or frequency encoding helps capture the distribution of categories in the dataset.

# %%
import pandas as pd

# Create a sample DataFrame with a categorical variable
data = pd.DataFrame({
    'Color': ['Red', 'Blue', 'Green', 'Blue', 'Red']
})

# Print the original data
print("Original data:")
print(data)

# Calculate frequency of each color using value_counts()
color_counts = data['Color'].value_counts()

# Create a dictionary to map colors to labels based on frequency with equal ranking for ties
color_labels = {color: count for color, count in color_counts.iteritems()}

# Apply count or frequency encoding using the map() function
data['Encoded_Color'] = data['Color'].map(color_labels)

# Print the encoded data
print("\nEncoded data:")
print(data)
# Out:
# Original data:
#    Color
# 0    Red
# 1   Blue
# 2  Green
# 3   Blue
# 4    Red
#
# Encoded data:
#    Color  Encoded_Color
# 0    Red              2
# 1   Blue              2
# 2  Green              1
# 3   Blue              2
# 4    Red              2
# <ipython-input-10-4bb59a16ccbb>:16: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   color_labels = {color: count for color, count in color_counts.iteritems()}

# %% [markdown]
# **4. Probability Ratio Encoding**

# %% [markdown]
# This encoding is purely based on probability. If it’s possible to calculate the probability or it’s a probability type problem, You can use this type of encoding by calculating the probabilities. For example, If you are working with some dataset like survive and not- survive in “Titanic Dataset”. There you can use probability encoding.

# %% [markdown]
# Suppose we have a dataset with a categorical variable "Category" and a binary target variable "Outcome" (1 for positive outcome, 0 for negative outcome). We want to perform Probability Ratio Encoding on the "Category" variable to encode it based on the likelihood of a positive outcome for each category. For example in analogy to the titanic datast the category could be the "cabin" feature and the outcome could be "survived" feature
#
# **Dataset:**
#
# | Category | Outcome |
# |----------|---------|
# | A        | 1       |
# | B        | 0       |
# | A        | 1       |
# | C        | 0       |
# | B        | 1       |
# | C        | 1       |
# | A        | 0       |
# | B        | 0       |
#
# **Step-by-Step Process:**
#
#  **1. Calculate Probability for Each Category and Target:**
#
#    Calculate the probability of a positive outcome (target = 1) and a negative outcome (target = 0) for each category:
#
#    | Category | P(Outcome=1) | P(Outcome=0) |
#    |----------|--------------|--------------|
#    | A        | 2/3 (0.67)   | 1/3 (0.33)   |
#    | B        | 1/3 (0.33)   | 2/3 (0.67)   |
#    | C        | 1/2 (0.50)   | 1/2 (0.50)   |
#
# **2. Calculate Probability Ratio:**
#
#    Calculate the probability ratio by dividing the probability of a positive outcome by the probability of a negative outcome for each category:
#
#    | Category | Probability Ratio |
#    |----------|-------------------|
#    | A        | 2.0               |
#    | B        | 0.5               |
#    | C        | 1.0               |
#
# **3. Map Categories to Probability Ratios:**
#
#    Replace the original "Category" categories with the calculated probability ratios:
#
#    | Category | Encoded Outcome Probability Ratio |
#    |----------|----------------------------------|
#    | A        | 2.0                              |
#    | B        | 0.5                              |
#    | A        | 2.0                              |
#    | C        | 1.0                              |
#    | B        | 0.5                              |
#    | C        | 1.0                              |
#    | A        | 2.0                              |
#    | B        | 0.5                              |
#
#
# **4. Apply Encoding to the Dataset:**
#
#    Map the probability ratio-encoded values to the original "Category" column:
#
#    | Category | Outcome | Encoded Outcome Probability Ratio |
#    |----------|---------|----------------------------------|
#    | A        | 1       | 2.0                              |
#    | B        | 0       | 0.5                              |
#    | A        | 1       | 2.0                              |
#    | C        | 0       | 1.0                              |
#    | B        | 1       | 0.5                              |
#    | C        | 1       | 1.0                              |
#    | A        | 0       | 2.0                              |
#    | B        | 0       | 0.5                              |
#
# In this example, Probability Ratio Encoding is applied to the "Category" variable. The encoding captures the likelihood of a positive outcome for each category. Categories with a higher probability of a positive outcome are assigned higher probability ratio-encoded values.

# %%
import pandas as pd

# Creating the dataset
data = {
    'Category': ['A', 'B', 'A', 'C', 'B', 'C', 'A', 'B'],
    'Outcome': [1, 0, 1, 0, 1, 1, 0, 0]
}

df = pd.DataFrame(data)

# Step 1: Calculate probability for each category and target
prob_df = df.groupby('Category')['Outcome'].mean()
prob_df = prob_df.to_frame(name='P(Outcome=1)')

# Calculate probability of no outcome (Outcome=0)
prob_df['P(Outcome=0)'] = 1 - prob_df['P(Outcome=1)']

# Step 2: Calculate probability ratio
prob_df['Probability Ratio'] = prob_df['P(Outcome=1)'] / prob_df['P(Outcome=0)']

# Step 3: Map categories to probability ratios
prob_encode = prob_df['Probability Ratio'].to_dict()
df['Encoded Outcome Probability Ratio'] = df['Category'].map(prob_encode)

# Display the encoded dataset
print(df)
# Out:
#   Category  Outcome  Encoded Outcome Probability Ratio
# 0        A        1                                2.0
# 1        B        0                                0.5
# 2        A        1                                2.0
# 3        C        0                                1.0
# 4        B        1                                0.5
# 5        C        1                                1.0
# 6        A        0                                2.0
# 7        B        0                                0.5

# %% [markdown]
# ### **Data Transformation**

# %% [markdown]
# It refers to putting the values in the same range or same scale so that no variable is dominated by the other.
#
# Most of the time, the collected data set contains features highly varying in magnitudes, units, and ranges. If scaling is not done then the algorithm only takes magnitude into account and not units hence incorrect modeling. To solve this issue, we have to do scaling to bring all the variables to the same level of magnitude.

# %% [markdown]
# #### **1.	Standardization**

# %% [markdown]
# Standardization is another scaling technique where the values are centered around the mean with a unit standard deviation. This means that the mean of the attribute becomes zero and the resultant distribution has a unit standard deviation.
#
# The standard score of a sample x is calculated as:
#
# z = (x - u) / s

# %%
from sklearn.preprocessing import StandardScaler
data = [[0, 0], [0, 0], [1, 1], [1, 1]]
scaler = StandardScaler()
print(scaler.fit(data))
print(scaler.mean_)
print(scaler.transform(data))
print(scaler.transform([[2, 2]]))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)
# [0.5 0.5]
# [[-1. -1.]
#  [-1. -1.]
#  [ 1.  1.]
#  [ 1.  1.]]
# [[3. 3.]]

# %% [markdown]
# #### **2.	Normalization**

# %% [markdown]
# Normalization is a scaling technique in which values are shifted and rescaled so that they end up ranging between 0 and 1. It is also known as Min-Max scaling.
#
# The transformation is given by:
#
# X_std = (X - X.min(axis=0)) / (X.max(axis=0) - X.min(axis=0))
#
# X_scaled = X_std * (max - min) + min

# %%
from sklearn.preprocessing import MinMaxScaler
data = [[-1, 2], [-0.5, 6], [0, 10], [1, 18]]
scaler = MinMaxScaler()
print(scaler.fit(data))
print(scaler.data_max_)
print(scaler.transform(data))
print(scaler.transform([[2, 2]]))
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))
# [ 1. 18.]
# [[0.   0.  ]
#  [0.25 0.25]
#  [0.5  0.5 ]
#  [1.   1.  ]]
# [[1.5 0. ]]

# %% [markdown]
# #### **3.	Robust Scalar**

# %% [markdown]
# It is used to scale the feature to median and quantile. Scaling using median and quantiles consists of subtracting the median from all the observations and then dividing by the interquartile difference. The inter quantile difference is the difference between the 75th and 25th.

# %%
from sklearn.preprocessing import RobustScaler
X = [[ 1., -2.,  2.],
    [ -2.,  1.,  3.],
    [ 4.,  1., -2.]]
transformer = RobustScaler().fit(X)
print(transformer)
print(transformer.transform(X))
# Out:
# RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#              with_scaling=True)
# [[ 0.  -2.   0. ]
#  [-1.   0.   0.4]
#  [ 1.   0.  -1.6]]

# %% [markdown]
# #### **4. Gaussian Transformation**

# %% [markdown]
# Some machine learning algorithms like linear and logistic regression assume that the features are normally distributed. So, we need to transform the features by the following methods.
#
# **Logarithmic Transformation:** Transforming using a logarithmic function.
#
#
# ```
# np.log(df[feature])
# ```
#
#
#
# **Inverse Transformation:** Transforming using an inverse function.
#
# ```
# 1/(df[feature])
# ```
#
# **Square Root Transformation:** Transforming using a square function.
#
# ```
# np.sqrt(df[feature])
# ```
#
#
# **Exponential Transformation:** Transforming using an exponential function.
# ```
# (df[feature])**(1/1.2)
# ```

# %% [markdown]
# #### **5. Box-Cox Transformation**

# %% [markdown]
# A Box-Cox transformation is a transformation of a non-normal dependent variable into a normal shape. Normality is an important assumption for many statistical techniques; if your data isn’t normal, applying a Box-Cox means that you can run a broader number of tests.
#
# The Box-Cox transformation is named after statisticians George Box and Sir David Roxbee Cox who collaborated on a 1964 paper and developed the technique.
#
# T(y)=(y exp(lambda)-1)/(lambda)
#
# where y is the response variable and ‘lambda’ is the transformation parameter from -5 to 5. In the transformation, all values of ‘lambda’ are considered and the optimal value for a given variable is selected.

# %%
#scipy.stats.boxcox(x, lmbda=None, alpha=None, optimizer=None)

# %%
from scipy import stats
import matplotlib.pyplot as plt

fig = plt.figure()
ax1 = fig.add_subplot(211)
x = stats.loggamma.rvs(5, size=500) + 5
prob = stats.probplot(x, dist=stats.norm, plot=ax1)
ax1.set_xlabel('')
ax1.set_title('Probplot against normal distribution')

ax2 = fig.add_subplot(212)
xt, _ = stats.boxcox(x)
prob = stats.probplot(xt, dist=stats.norm, plot=ax2)
ax2.set_title('Probplot after Box-Cox transformation')

plt.show()

# %% [markdown]
# ### **Feature Selection**

# %% [markdown]
# Feature selection is the process of reducing the number of input variables when developing a predictive model.
# It is desirable to reduce the number of input variables to both reduce the computational cost of modeling and, in some cases, to improve the performance of the model.

# %% [markdown]
# **1. Using Pearson Correlation**

# %% [markdown]
# A Pearson correlation is a number between -1 and 1 that indicates the extent to which two variables are linearly related. The Pearson correlation is also known as the “product moment correlation coefficient” (PMCC) or simply “correlation”
#
# Pearson correlations are suitable only for metric variables
# The correlation coefficient has values between -1 to 1
#
# •	A value closer to 0 implies weaker correlation (exact 0 implying no correlation)
#
# •	A value closer to 1 implies stronger positive correlation
#
# •	A value closer to -1 implies stronger negative correlation

# %%
#Example Code
def correlation(df, threshold):
    col_corr = set()  # Set to store correlated column names
    corr_matrix = df.corr()  # Calculate the correlation matrix

    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            corr_value = corr_matrix.iloc[i, j]  # Get the correlation value
            if abs(corr_value) > threshold:
                colname = corr_matrix.columns[i]  # Get the name of the correlated column
                col_corr.add((colname, corr_value))  # Add the column name and correlation value to the set

    return col_corr  # Return the set of correlated column names and their correlation values

# %% [markdown]
# Here's how you can use the funtion with the example DataFrame:

# %%
import pandas as pd

# Create a sample DataFrame
data = {
    'Feature1': [1, 2, 3, 4, 5],
    'Feature2': [5, 4, 3, 2, 1],
    'Feature3': [2, 2, 2, 2, 2],
    'Target': [0, 1, 0, 1, 0]
}

df = pd.DataFrame(data)

# Define the correlation threshold
threshold = 0.5

# Call the correlation function
highly_correlated_info = correlation(df, threshold)

print("Columns with high correlation:")
for colname, corr_value in highly_correlated_info:
    print(f"{colname} with correlation value: {corr_value}")
# Out:
# Columns with high correlation:
# Feature2 with correlation value: -1.0

# %%
# Alternate way
# Calculate Pearson correlation matrix
correlation_matrix = df.corr()

# Visualize the correlation matrix using a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title("Pearson Correlation Heatmap")
plt.show()

# %% [markdown]
# **2. Variable inflation Factor**

# %% [markdown]
# Collinearity is the state where two variables are highly correlated and contain similar information about the variance within a given dataset. To detect collinearity among variables, simply create a correlation matrix and find variables with large absolute values.
#
# Steps for Implementing VIF
#
# •	Calculate the VIF .
#
# •	Inspect the factors for each predictor variable, if the VIF is between 5–10, multicollinearity is likely present and you should consider dropping the variable.
#
# In VIF method, we pick each feature and regress it against all of the other features. For each regression, the factor is calculated as :
#
# VIF=$\frac{1}{1-R^2}$
#
# Where, R-squared is the coefficient of determination in linear regression. Its value lies between 0 and 1.

# %%
import pandas as pd
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Create a sample dataset
data = {
    'Income': [50000, 60000, 70000, 55000, 75000],
    'Age': [28, 32, 45, 29, 38],
    'Experience': [5, 8, 15, 6, 10],
    'Target': [1, 0, 1, 0, 1]
}

df = pd.DataFrame(data)

# Separate features and target variable
X = df[['Income', 'Age', 'Experience']]
y = df['Target']

# Calculate VIF for each variable
vif_data = pd.DataFrame()
vif_data["Variable"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

print("VIF values:")
print(vif_data)
# Out:
# VIF values:
#      Variable         VIF
# 0      Income  210.194656
# 1         Age  385.709740
# 2  Experience   46.284131

# %% [markdown]
# **3. Forward Elimination**

# %% [markdown]
# Forward selection is an iterative method in which we start with having no feature in the model. In each iteration, we keep adding the feature which best improves our model till an addition of a new variable does not improve the performance of the model.

# %%
def forward_elimination (x,y):
  from sklearn.linear_model import LogisticRegression
  lr=LogisticRegression()
  from mlxtend.feature_selection import SequentialFeatureSelector
  ffs= SequentialFeatureSelector(lr, k_features="best", forward= True, n_jobs=-1)
  ffs.fit(x,y)
  features=list(ffs.k_feature_names_)
  return features

# %% [markdown]
# **4.	Backward Elimination**

# %% [markdown]
# In backward elimination, we start with all the features and removes the least significant feature at each iteration which improves the performance of the model. We repeat this until no improvement is observed on removal of features.

# %%
def backward_elimination (x,y):
  from sklearn.linear_model import LogisticRegression
  lr=LogisticRegression()
  from mlxtend.feature_selection import SequentialFeatureSelector
  bfs=SequentialFeatureSelector(lr, k_features="best",forward=False, n_jobs=-1)
  bfs.fit(x_train,y_train)
  features= list(bfs.k_feature_names_)
  return features

# %% [markdown]
# **5. Recursive Feature elimination**

# %% [markdown]
# It is a greedy optimization algorithm which aims to find the best performing feature subset. It repeatedly creates models and keeps aside the best or the worst performing feature at each iteration. It constructs the next model with the left features until all the features are exhausted. It then ranks the features based on the order of their elimination.

# %%
def recursive_elimination(x_train,y_train,x_test,y_test):
  from sklearn.feature_selection import RFE
  rfe=RFE(lr,n_features_to_select=7)
  rfe.fit(x_train,y_train)
  y_pred=rfe.predict(x_test)
  return y_pred

# %% [markdown]
# **6. Embedded Method**

# %% [markdown]
# Embedded methods are iterative in a sense that takes care of each iteration of the model training process and carefully extract those features which contribute the most to the training for a particular iteration.

# %% [markdown]
# In this example, we load the Iris dataset from sklearn.datasets. The dataset contains features related to iris flowers and a target variable "Species" representing the species of the iris flowers. The embedded_feature_selection function is used with Lasso Regression to perform feature selection. The alpha parameter is set to 0.01 for regularization.
#
# Please note that the Iris dataset is used for illustrative purposes, and the concept of embedded feature selection can be applied to more complex datasets as well.

# %%
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.linear_model import Lasso

def embedded_feature_selection(X, y, alpha=1.0):
    model = Lasso(alpha=alpha)
    model.fit(X, y)
    selected_features = X.columns[model.coef_ != 0]
    return selected_features

# Load the Iris dataset
iris_data = load_iris()
X = pd.DataFrame(iris_data.data, columns=iris_data.feature_names)
y = pd.Series(iris_data.target, name='Species')

# Call the embedded_feature_selection function
selected_features = embedded_feature_selection(X, y, alpha=0.01)

print("Selected features:", selected_features)
# Out:
# Selected features: Index(['sepal length (cm)', 'petal length (cm)', 'petal width (cm)'], dtype='object')

# %% [markdown]
# **7. Dropping Constant Feature**

# %% [markdown]
# Dropping constant features using the VarianceThreshold method is a common technique in feature selection. It involves identifying features that have very low variance (close to zero) across the dataset and removing them. Features with low variance typically provide little information and are unlikely to contribute much to the predictive power of a model.

# %%
#Example
import pandas as pd
from sklearn.feature_selection import VarianceThreshold

# Create a sample DataFrame
data = {
    'Feature1': [1, 2, 3, 4, 5],
    'Feature2': [5, 5, 5, 5, 5],
    'Feature3': [2, 2, 2, 2, 2],
    'Target': [0, 1, 0, 1, 0]
}

df = pd.DataFrame(data)

# Separate features and target variable
X = df.drop('Target', axis=1)

# Create a VarianceThreshold instance
threshold = 0.0  # Variance threshold to consider
vt = VarianceThreshold(threshold=threshold)

# Fit and transform the features using VarianceThreshold
X_transformed = vt.fit_transform(X)

# Get the indices of selected features
selected_indices = vt.get_support(indices=True)

# Get the names of selected features
selected_features = X.columns[selected_indices]

print("Original DataFrame:")
print(X)
print("\nSelected features after dropping constant features:")
print(selected_features)
# Out:
# Original DataFrame:
#    Feature1  Feature2  Feature3
# 0         1         5         2
# 1         2         5         2
# 2         3         5         2
# 3         4         5         2
# 4         5         5         2
#
# Selected features after dropping constant features:
# Index(['Feature1'], dtype='object')

# %% [markdown]
# **8. Fisher Score**
#
# Fisher Score is a statistical method used for feature selection to identify the importance of each feature in distinguishing between different classes or groups within the target variable. It is particularly useful for classification problems with categorical or discrete features. Fisher Score is based on the Fisher's Discriminant Ratio, which quantifies the ratio of the variance between classes to the variance within classes.
#
# **Here's how Fisher Score works:**
#
# - **Calculate Mean and Variance:** Compute the mean and variance of each feature for each class separately.
# Calculate the mean of each feature across all classes and the total variance within each class.
#
# - **Calculate Fisher's Discriminant Ratio (FDR):** The Fisher's Discriminant Ratio for a feature is calculated as the ratio of the between-class variance to the within-class variance.
# Select Features:
#
# Features with higher Fisher's Discriminant Ratio are considered more important, as they exhibit higher variance between classes compared to the variance within classes.Select the top features with the highest FDR values as they contribute the most to the separability between classes.
#
# Here's an example of implementing Fisher Score for feature selection in Python using the sklearn library:

# %%
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# Load the Iris dataset
iris_data = load_iris()
X = pd.DataFrame(iris_data.data, columns=iris_data.feature_names)
y = pd.Series(iris_data.target, name='Species')

# Select the top 2 features using Fisher Score
num_features = 2
fisher_selector = SelectKBest(chi2, k=num_features)
X_selected = fisher_selector.fit_transform(X, y)

# Get the indices of selected features
selected_indices = fisher_selector.get_support(indices=True)

# Get the names of selected features
selected_features = X.columns[selected_indices]

print("Selected features using Fisher Score:")
print(selected_features)
# Out:
# Selected features using Fisher Score:
# Index(['petal length (cm)', 'petal width (cm)'], dtype='object')

# %% [markdown]
# **Note**:  All the above code examples are just for illustration to show  how to implement different feature selection methods. Please ensure  these techniques are implemented based on the business usecase.

# %% [markdown]
# #### **Univariate Feature Selection**

# %% [markdown]
# **(1) use chi-square test.**

# %% [markdown]
# For more information about the chi-square test, read:
#
# •	statistics: http://vassarstats.net/textbook/, chapter 8
#
# •	Sklearn: https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.chi2.html#sklearn.feature_selection.chi2
#
# Read the source code if you want to know more about how Sklearn apply chi-square test: https://github.com/scikit-learn/scikit-learn/blob/1495f6924/sklearn/feature_selection/univariate_selection.py#L172
#
# The first four elements in the array are true, which means the first four features were selected by this method. Since these features are the original features in the data, the chi-square test performs well.

# %% [markdown]
# **(2) use f test**

# %% [markdown]
# •	statistics
#
# one-way ANOVA :
# http://vassarstats.net/textbook/, chapter 14
#
# ANOVA for regression:
# http://facweb.cs.depaul.edu/sjost/csc423/documents/f-test-reg.htm
#
# •	Sklearn
#
# f test for classification:
# https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.f_classif.html#sklearn.feature_selection.f_classif
#
# f test for regression:
# https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.f_regression.html#sklearn.feature_selection.f_regression
#
# The f test can also correctly select the original features.

# %% [markdown]
# **(3) use mutual_info_classif test**

# %% [markdown]
# •	for classification: https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.mutual_info_classif.html#sklearn.feature_selection.mutual_info_classif
#
# •	for regression: https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.mutual_info_regression.html#sklearn.feature_selection.mutual_info_regression

# %% [markdown]
# ### **Other Methods of Feature Selection:**

# %% [markdown]
# #### **Wrapper Methods:** 🤲🔍

# %% [markdown]
# Wrapper methods evaluate feature subsets by training and evaluating models iteratively. Examples include forward selection, backward elimination, and recursive feature elimination. It's like trying on different outfits to find the one that fits best!

# %%
# Wrapper Methods - Recursive Feature Elimination (RFE)
estimator = RandomForestClassifier()  # Use RandomForestClassifier as the estimator
rfe = RFE(estimator, n_features_to_select=3)  # Select 3 features
X_rfe = rfe.fit_transform(X_scaled, y)

# Print the results
print("\nWrapper Methods - Recursive Feature Elimination (RFE):")
print(X_rfe)
# Out:
# Wrapper Methods - Recursive Feature Elimination (RFE):
# [[-1.41421356 -1.41421356 -1.41421356]
#  [-0.70710678 -0.70710678 -0.70710678]
#  [ 0.          0.          0.        ]
#  [ 0.70710678  0.70710678  0.70710678]
#  [ 1.41421356  1.41421356  1.41421356]]

# %% [markdown]
# - **RFE** is a wrapper method that recursively eliminates features by training an estimator (in this case, **RandomForestClassifier**) and removing the least important features.
# - **rfe.fit_transform(X_scaled, y)** fits the RFE model and transforms the input features **X_scaled** to select the desired number of features (in this case, 3).
# - The selected features are stored in **X_rfe**.

# %% [markdown]
# #### **Embedded Methods:** 🌿🔍

# %% [markdown]
# Embedded methods incorporate feature selection within the model training process itself, like regularization techniques (e.g., Lasso, Ridge regression) or decision tree-based algorithms (e.g., Random Forest, Gradient Boosting). It's like having a smart model that selects features while learning!

# %%
# Embedded Methods - SelectFromModel (L1-based)
model = RandomForestClassifier()  # Use RandomForestClassifier as the estimator
sfm = SelectFromModel(model, threshold='mean')  # Select features with coefficients above mean
X_embedded = sfm.fit_transform(X_scaled, y)

# Print the results
print("\nEmbedded Methods - SelectFromModel (L1-based):")
print(X_embedded)
# Out:
# Embedded Methods - SelectFromModel (L1-based):
# [[-1.41421356 -1.41421356 -1.41421356]
#  [-0.70710678 -0.70710678 -0.70710678]
#  [ 0.          0.          0.        ]
#  [ 0.70710678  0.70710678  0.70710678]
#  [ 1.41421356  1.41421356  1.41421356]]

# %% [markdown]
# - **SelectFromModel** is an embedded method that selects features based on the importance coefficients obtained from an estimator.
# - **sfm.fit_transform(X_scaled, y)** fits the SelectFromModel model (using **RandomForestClassifier**) and transforms the input features **X_scaled** to select the features with coefficients above the mean threshold.
# - The selected features are stored in **X_embedded**.

# %% [markdown]
# #### **Information-Theoretic Methods:** 📚🔍

# %% [markdown]
# Information-theoretic methods, like mutual information or entropy, measure the amount of information one feature provides about the target variable. It's like quantifying the knowledge gain each feature brings!

# %%
# Information-Theoretic Methods - Mutual Information
# You can use feature_selection.mutual_info_classif or mutual_info_regression functions
# Print the results
print("\nInformation-Theoretic Methods - Mutual Information:")
# Print the selected features using mutual information
# Out:
# Information-Theoretic Methods - Mutual Information:

# %% [markdown]
# - The specific function for calculating mutual information (**feature_selection.mutual_info_classif** or **mutual_info_regression**) is not shown in the code.
# - Mutual information is an information-theoretic method used to measure the dependency between features and the target variable.
# - It provides a score for each feature, which can be used for feature selection.

# %% [markdown]
# ### <b> Learning the math behind PCA </b>

# %% [markdown]
# <b> Step 1 : Take the whole dataset with dimension $d$ (which corresponds to the $d$ features) </b>
#
#
# <b> Step 2 : Compute the mean of every dimension of the whole dataset. </b>
#
# <b> Step 3 : Compute the covariance matrix of the whole dataset </b>
# * ### \begin{align*}
#   Cov(X,Y) &= \frac{1}{n-1}\sum_{i=1}^{n} (X_{i} - \bar X)(Y_{i} - \bar Y) \\
# \end{align*}
#
# <b> Step 4 : Compute Eigenvectors and corresponding Eigenvalues for the covariance matrix A </b>
# * Let A be a square matrix, ν a vector and λ a scalar that satisfies $Aν = λν$, then λ is called eigenvalue associated with eigenvector ν of A.
#
# <b> Step 5 : Sort the eigenvectors by decreasing eigenvalues and choose $k$ eigenvectors with the largest eigenvalues to form a $d × k$ dimensional matrix $W$. </b>
#
# <b> Step 6 : Transform the samples onto the new subspace</b>
# * In the last step, we use the $d × k$ dimensional matrix $W$ that we just computed to transform our samples onto the new subspace via the equation $y = W′ × x$ where $W′$ is the transpose of the matrix $W$.

# %% [markdown]
# ##**📖Additional Reference Paper📖**
# **1. How to Handle Missing Data in a Dataset** :- https://www.freecodecamp.org/news/how-to-handle-missing-data-in-a-dataset/
#
# **2. Feature Engineering for Machine Learning** :- https://serokell.io/blog/feature-engineering-for-machine-learning

# %% [markdown]
# ##🤖🌲**Mnemonic**🕵️‍♂️🦉

# %% [markdown]
# Once upon a time, in a magical forest, there lived a curious young wizard named Alex. Alex was passionate about machine learning and wanted to build powerful models using the enchanted data in the forest. However, the forest was full of mysteries, and the data was not always perfect.
#
# One sunny morning, while wandering through the forest, Alex stumbled upon a peculiar tree with missing leaves. It was the "Handling Missing Values" tree. To bring back its full glory, Alex used the power of mean, median, and mode spells. The missing leaves reappeared, making the tree complete again.
#
# As Alex explored further, they encountered a magnificent waterfall where two streams merged. It was the "Bivariate Analysis" waterfall, where X and Y streams combined. Alex noticed that when the streams aligned perfectly, the waterfall's flow was smooth, indicating a strong relationship. They decided to record this magical bond in a two-column data table, uncovering hidden patterns.
#
# Continuing their journey, Alex discovered a grand garden with various plants and flowers. Each plant represented a different feature in the dataset. This was the "Multivariate Analysis" garden, where multiple factors contributed to the plants' growth. Alex realized that understanding these factors was crucial for predicting the forest's future.
#
# Among the plants, Alex found a special patch where the Age plants were missing. To solve this, they created a new magical feature, "Age_nan," with 1 for missing values and 0 for non-missing values. This way, they could keep track of the Age plants and their growth in the enchanted forest.
#
# Deep in the forest, Alex encountered an ancient temple called "End of Distribution Imputation." Here, they discovered sacred values at the tails of the distribution that could replace missing values when patterns were suspicious. It was a powerful technique to maintain the sanctity of the data.
#
# Feeling accomplished, Alex decided to share their knowledge with the other wizards in the magical forest. They invited everyone to a grand gathering at the "Comprehensive Review Hall," where they presented their findings. The wizards were amazed to learn about "Feature Scaling," "Feature Selection," "Encoding Categorical Variables," "Embedding," and "Dimensionality Reduction."
#
# The enchanted forest was now abuzz with the magic of feature engineering. Alex's tale spread far and wide, inspiring wizards from all realms to enhance their models using these techniques. The forest became a hub of innovation and excellence in machine learning.
#
# And so, the story of Alex's magical journey through the Forest of Feature Engineering became a legend, passed down from one generation of wizards to the next, guiding them in their pursuit of powerful machine learning models.

# %% [markdown]
# # **Try it Yourself:**

# %% [markdown]
# ### **Task 1: Working on assignment**

# %% [markdown]
# **Problem Statement: Predicting Survival on the Titanic**
#
# **Scenario:**
# You are part of a data science team working for a historical preservation society. Your organization is interested in understanding the factors that influenced passenger survival rates on the Titanic, a famous passenger ship that tragically sank in 1912. Your goal is to build a predictive model to determine the likelihood of survival for passengers based on their characteristics and features.
#
# **Dataset:**
#
# [dataset](https://drive.google.com/file/d/1_ke3IKkPjn3pJ0j1pNwa9B63GKgykgTM/view?usp=sharing). Download the dataset and upload it to your drive
#
# You have been provided with a dataset containing information about passengers who were on board the Titanic. This dataset includes details such as passenger names, ages, genders, ticket classes, fares, and more. Additionally, it includes a binary target variable "Survived," where 1 indicates that the passenger survived the disaster, and 0 indicates otherwise.
#
# **Tasks:**
#
# 1. **Data Preprocessing:**
#    - Handle missing values in the dataset, ensuring that there are no gaps in the data.
#    - Detect and remove any outliers that might skew the analysis.
#
# 2. **Feature Engineering:**
#    - Encode categorical variables like "Sex" and "Embarked" into numerical formats for modeling.
#    - Select the most relevant features for the prediction task.
#    - Reduce the dimensionality of the dataset while retaining critical information using PCA.
#
# 3. **Modeling:**
#    - Split the preprocessed dataset into training and testing sets.
#    - Build a predictive model, such as logistic regression or a decision tree classifier, to predict passenger survival.
#    - Evaluate the model's performance using appropriate metrics, such as accuracy or F1 score.
